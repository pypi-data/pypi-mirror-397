# %% [markdown]
# # `H2MM_C` Displaying Optimization Progress
#
# Let's get our obligitory imports in order, and we'll load the 3 detector data as well.

# %%
import os
import numpy as np
from matplotlib import pyplot as plt

import H2MM_C as hm


# load the data
def load_txtdata(filename):
    color = list()
    times = list()
    with open(filename,'r') as f:
        for i, line in enumerate(f):
            if i % 2 == 0:
                times.append(np.array([int(x) for x in line.split()],dtype=np.int64))
            else:
                color.append(np.array([int(x) for x in line.split()],dtype=np.uint8))
    return color, times

color3, times3 = load_txtdata('sample_data_3det.txt')

# %% [markdown]
# ## Customizing Display of Optmization progression
#
# You've probably seen that whenever `hm.EM_H2MM_C()` is run, you see the number of iterations currently computed gets displayed. This behavior can be modified however with the `print_func` keyword argument. This lets us choose how much/what information gets displayed! See the list of options below:
#
#
# ### Basic `print_func` options
#
# - `'iter'` Prints only the iteration number- compact way to still track optimization progress in Jupyter Notebook
# - `'all'` prints a representation of the whole model to be optimized in the next iteration (this will be very verbose).
# - `'diff'` Print the difference between the previous and current model logliklihoods and the current loglikelihood.
# - `'diff_time'` Same as `'diff'` but with additional information about how long the current iteration took, and the total time taken. These times however are not very accurate, because they use an inaccurate, but fast clock function.
# - `'comp'` Print the old and current loglikelihoods
# - `'comp_time'` Like `'diff_time'` but for `'comp'`
# - `None` Suppresses all printing of iteration information.

# %%
model_3d3c = hm.EM_H2MM_C(hm.factory_h2mm_model(3,3), color3,  times3, print_func='diff')
# Out:
# The model converged after 198 iterations

# %% [markdown]
# ### Changing frequence of Display updates with `print_freq`
#
# `print_freq` is used to specify how frequently the display updates, by passing an *integer* value into `print_freq`, then the display will only update after that many iterations.
#
# Update the display every 10 iterations:

# %%
model_3d3c = hm.EM_H2MM_C(hm.factory_h2mm_model(3,3), color3,  times3, print_func='diff', print_freq=10)
# Out:
# The model converged after 201 iterations

# %% [markdown]
# ## Customized display using your own function
#
# If you want to customize the display, you can define  your own printing function.
#
# The function should have the following general signature:
#
# `print_func(niter:int, new_model:h2mm_model, current_model:h2mm_model, old_model:h2mm_model, iter_time:int, total_time:float)->str`
#
# > **NOTE**
# >
# > It is not necessary, but recommended to keep these variable names in the function declaration.
#
# where:
# - `niter` is the number of iterations
# - `new_model` is a `h2mm_model` object that represents the next model to be optimized (**before** checking for out of bounds values) note that its `.loglik` will be irrelevant because it has not been calculated yet.
# - `current_model` is a `h2mm_model` object that represents the model whose `.loglik` was just calculated
# - `old_model` is a `h2mm_model` object that represents the model from the previous iteration.
# - `iter_time` is a float which is the time in seconds based on the **inaccurate C clock** that it took to calculate the latest iteration
# - `total_time` is a float which is the time in seconds based on the **inaccurate C clock** that the full optimization has taken
#
# The output of `print_func` is converted to a string (`str()`) and displayed, unless `print_func` returns `None`, in which case nothing is printed (unless `print_func` internally calls its own print method)
#
# So below is an example of a custom print function:

# %%
def silly_print(niter, new, current, old, titer, time):
    return (f"We haven't finished after {niter} iterations " 
           f"with {new.loglik - current.loglik} improvement "
           f"in loglik after {time} (inaccurate) seconds")

# %%
hm.EM_H2MM_C(hm.factory_h2mm_model(3,3), color3, times3, print_func=silly_print, print_freq=10)
# Out:
# The model converged after 198 iterations
# nstate: 3, ndet: 3, nphot: 436084, niter: 198, loglik: -409379.14701993956 converged state: 0x27
# prior:
# 0.2599161087080881, 0.49437683694695067, 0.2457070543449613
# trans:
# 0.9999762009962716, 2.1091569337996854e-05, 2.7074343903649633e-06
# 8.392846121801916e-06, 0.9999812080448961, 1.0399108982083962e-05
# 6.290283042355416e-06, 4.466216582383375e-05, 0.9999490475511338
# obs:
# 0.14570423954876852, 0.2934431830052035, 0.560852577446028
# 0.4417395147706429, 0.0876310597860471, 0.4706294254433099
# 0.8414287880015665, 0.07852868417810849, 0.08004252782032498

# %% [markdown]
# ### Passing additional args to `print_func` with `print_args`
#
# The true signature of print_args is
#
# `print_func(niter:int, new_model:h2mm_model, current_model:h2mm_model, old_model:h2mm_model, t_iter:int, t_total:float, *print_args, **print_kwargs)->str`
#
# `EM_H2MM_C` has two keyword arguments, `print_args` and `print_kwargs`, only used when `print_func` is a callable, which are passed to `print_func` as
# its args and kwargs. Note that in both cases, a value of `None` is converted into an empty tuple/dict respectively. Further, if a non-tuple is passed
# to `print_args` it is treated as a single argument.)

# %%
def silly_print_arg_kwarg(niter, new, current, old, titer, time, *args, modulus=None):
    return f"niter={niter} args={args}, modulus={modulus}"

# %%
hm.EM_H2MM_C(hm.factory_h2mm_model(3,3), color3, times3, 
             print_func=silly_print_arg_kwarg, print_args="I'm very silly", print_kwargs=dict(modulus=1))
# Out:
# The model converged after 198 iterations
# nstate: 3, ndet: 3, nphot: 436084, niter: 198, loglik: -409379.14701993956 converged state: 0x27
# prior:
# 0.2599161087080877, 0.4943768369469518, 0.24570705434496054
# trans:
# 0.9999762009962716, 2.109156933799686e-05, 2.707434390364933e-06
# 8.392846121801852e-06, 0.9999812080448961, 1.0399108982083884e-05
# 6.29028304235531e-06, 4.4662165823833885e-05, 0.9999490475511338
# obs:
# 0.1457042395487681, 0.2934431830052031, 0.5608525774460288
# 0.44173951477064244, 0.08763105978604725, 0.4706294254433104
# 0.8414287880015672, 0.07852868417810839, 0.08004252782032449

# %% [markdown]
# ## Advanced options: Formatter
#
# By default, optimization progress is printed to `sys.stdout`, and each update over-writes the previous update.
# This is done using the `print_formatter`.
#
# ### Keeping display of each iteration
#
# The default `print_formatter` has a single keyword argument: `keep`.
# We can set this using the `print_fmt_kwargs` keyword argument in `EM_H2MM_C`,
# if it is set to `True`, then the text of each new iteration will be displayed on a new line.

# %%
model_3d3c = hm.EM_H2MM_C(hm.factory_h2mm_model(3,3), color3,  times3, print_func='diff', print_fmt_kwargs=dict(keep=True))
# Out:
# Iteration:    0, loglik:-4.387899e+05, improvement:   inf
# Iteration:    1, loglik:-4.203991e+05, improvement:1.839076e+04
# Iteration:    2, loglik:-4.172495e+05, improvement:3.149621e+03
# Iteration:    3, loglik:-4.168160e+05, improvement:4.334909e+02
# Iteration:    4, loglik:-4.166697e+05, improvement:1.463433e+02
# Iteration:    5, loglik:-4.165714e+05, improvement:9.831467e+01
# Iteration:    6, loglik:-4.164868e+05, improvement:8.460410e+01
# Iteration:    7, loglik:-4.164030e+05, improvement:8.370726e+01
# Iteration:    8, loglik:-4.163116e+05, improvement:9.142352e+01
# Iteration:    9, loglik:-4.162055e+05, improvement:1.061152e+02
# Iteration:   10, loglik:-4.160785e+05, improvement:1.269588e+02
# Iteration:   11, loglik:-4.159256e+05, improvement:1.529380e+02
# Iteration:   12, loglik:-4.157447e+05, improvement:1.808611e+02
# Iteration:   13, loglik:-4.155401e+05, improvement:2.046643e+02
# Iteration:   14, loglik:-4.153189e+05, improvement:2.211944e+02
# Iteration:   15, loglik:-4.150866e+05, improvement:2.322782e+02
# Iteration:   16, loglik:-4.148451e+05, improvement:2.415008e+02
# Iteration:   17, loglik:-4.145964e+05, improvement:2.486755e+02
# Iteration:   18, loglik:-4.143435e+05, improvement:2.529542e+02
# Iteration:   19, loglik:-4.140881e+05, improvement:2.554187e+02
# Iteration:   20, loglik:-4.138319e+05, improvement:2.561196e+02
# Iteration:   21, loglik:-4.135787e+05, improvement:2.532579e+02
# Iteration:   22, loglik:-4.133311e+05, improvement:2.475722e+02
# Iteration:   23, loglik:-4.130892e+05, improvement:2.418696e+02
# Iteration:   24, loglik:-4.128514e+05, improvement:2.378508e+02
# Iteration:   25, loglik:-4.126157e+05, improvement:2.356415e+02
# Iteration:   26, loglik:-4.123811e+05, improvement:2.346992e+02
# Iteration:   27, loglik:-4.121466e+05, improvement:2.344752e+02
# Iteration:   28, loglik:-4.119119e+05, improvement:2.346358e+02
# Iteration:   29, loglik:-4.116771e+05, improvement:2.348715e+02
# Iteration:   30, loglik:-4.114426e+05, improvement:2.344301e+02
# Iteration:   31, loglik:-4.112106e+05, improvement:2.320622e+02
# Iteration:   32, loglik:-4.109840e+05, improvement:2.266024e+02
# Iteration:   33, loglik:-4.107665e+05, improvement:2.175059e+02
# Iteration:   34, loglik:-4.105615e+05, improvement:2.049792e+02
# Iteration:   35, loglik:-4.103717e+05, improvement:1.897585e+02
# Iteration:   36, loglik:-4.101993e+05, improvement:1.724524e+02
# Iteration:   37, loglik:-4.100461e+05, improvement:1.531493e+02
# Iteration:   38, loglik:-4.099140e+05, improvement:1.321656e+02
# Iteration:   39, loglik:-4.098032e+05, improvement:1.107497e+02
# Iteration:   40, loglik:-4.097127e+05, improvement:9.049932e+01
# Iteration:   41, loglik:-4.096402e+05, improvement:7.254715e+01
# Iteration:   42, loglik:-4.095828e+05, improvement:5.736204e+01
# Iteration:   43, loglik:-4.095379e+05, improvement:4.492736e+01
# Iteration:   44, loglik:-4.095029e+05, improvement:3.497448e+01
# Iteration:   45, loglik:-4.094758e+05, improvement:2.713812e+01
# Iteration:   46, loglik:-4.094547e+05, improvement:2.103855e+01
# Iteration:   47, loglik:-4.094384e+05, improvement:1.632438e+01
# Iteration:   48, loglik:-4.094257e+05, improvement:1.269319e+01
# Iteration:   49, loglik:-4.094158e+05, improvement:9.897353e+00
# Iteration:   50, loglik:-4.094081e+05, improvement:7.740962e+00
# Iteration:   51, loglik:-4.094020e+05, improvement:6.072558e+00
# Iteration:   52, loglik:-4.093972e+05, improvement:4.776702e+00
# Iteration:   53, loglik:-4.093935e+05, improvement:3.766078e+00
# Iteration:   54, loglik:-4.093905e+05, improvement:2.974800e+00
# Iteration:   55, loglik:-4.093881e+05, improvement:2.353085e+00
# Iteration:   56, loglik:-4.093863e+05, improvement:1.863156e+00
# Iteration:   57, loglik:-4.093848e+05, improvement:1.476176e+00
# Iteration:   58, loglik:-4.093836e+05, improvement:1.169979e+00
# Iteration:   59, loglik:-4.093827e+05, improvement:9.274102e-01
# Iteration:   60, loglik:-4.093820e+05, improvement:7.351031e-01
# Iteration:   61, loglik:-4.093814e+05, improvement:5.825859e-01
# Iteration:   62, loglik:-4.093809e+05, improvement:4.616147e-01
# Iteration:   63, loglik:-4.093805e+05, improvement:3.656763e-01
# Iteration:   64, loglik:-4.093803e+05, improvement:2.896107e-01
# Iteration:   65, loglik:-4.093800e+05, improvement:2.293229e-01
# Iteration:   66, loglik:-4.093798e+05, improvement:1.815592e-01
# Iteration:   67, loglik:-4.093797e+05, improvement:1.437336e-01
# Iteration:   68, loglik:-4.093796e+05, improvement:1.137899e-01
# Iteration:   69, loglik:-4.093795e+05, improvement:9.009406e-02
# Iteration:   70, loglik:-4.093794e+05, improvement:7.134806e-02
# Iteration:   71, loglik:-4.093794e+05, improvement:5.652128e-02
# Iteration:   72, loglik:-4.093793e+05, improvement:4.479605e-02
# Iteration:   73, loglik:-4.093793e+05, improvement:3.552413e-02
# Iteration:   74, loglik:-4.093793e+05, improvement:2.819196e-02
# Iteration:   75, loglik:-4.093792e+05, improvement:2.239293e-02
# Iteration:   76, loglik:-4.093792e+05, improvement:1.780534e-02
# Iteration:   77, loglik:-4.093792e+05, improvement:1.417483e-02
# Iteration:   78, loglik:-4.093792e+05, improvement:1.130034e-02
# Iteration:   79, loglik:-4.093792e+05, improvement:9.023061e-03
# Iteration:   80, loglik:-4.093792e+05, improvement:7.217581e-03
# Iteration:   81, loglik:-4.093792e+05, improvement:5.784889e-03
# Iteration:   82, loglik:-4.093792e+05, improvement:4.646830e-03
# Iteration:   83, loglik:-4.093792e+05, improvement:3.741736e-03
# Iteration:   84, loglik:-4.093792e+05, improvement:3.020919e-03
# Iteration:   85, loglik:-4.093792e+05, improvement:2.445987e-03
# Iteration:   86, loglik:-4.093792e+05, improvement:1.986612e-03
# Iteration:   87, loglik:-4.093792e+05, improvement:1.618845e-03
# Iteration:   88, loglik:-4.093792e+05, improvement:1.323802e-03
# Iteration:   89, loglik:-4.093792e+05, improvement:1.086527e-03
# Iteration:   90, loglik:-4.093792e+05, improvement:8.952320e-04
# Iteration:   91, loglik:-4.093792e+05, improvement:7.405710e-04
# Iteration:   92, loglik:-4.093792e+05, improvement:6.151432e-04
# Iteration:   93, loglik:-4.093792e+05, improvement:5.131030e-04
# Iteration:   94, loglik:-4.093791e+05, improvement:4.298042e-04
# Iteration:   95, loglik:-4.093791e+05, improvement:3.615516e-04
# Iteration:   96, loglik:-4.093791e+05, improvement:3.054257e-04
# Iteration:   97, loglik:-4.093791e+05, improvement:2.590740e-04
# Iteration:   98, loglik:-4.093791e+05, improvement:2.206537e-04
# Iteration:   99, loglik:-4.093791e+05, improvement:1.886736e-04
# Iteration:  100, loglik:-4.093791e+05, improvement:1.619296e-04
# Iteration:  101, loglik:-4.093791e+05, improvement:1.394848e-04
# Iteration:  102, loglik:-4.093791e+05, improvement:1.205522e-04
# Iteration:  103, loglik:-4.093791e+05, improvement:1.045348e-04
# Iteration:  104, loglik:-4.093791e+05, improvement:9.091123e-05
# Iteration:  105, loglik:-4.093791e+05, improvement:7.928576e-05
# Iteration:  106, loglik:-4.093791e+05, improvement:6.932864e-05
# Iteration:  107, loglik:-4.093791e+05, improvement:6.076344e-05
# Iteration:  108, loglik:-4.093791e+05, improvement:5.337037e-05
# Iteration:  109, loglik:-4.093791e+05, improvement:4.697789e-05
# Iteration:  110, loglik:-4.093791e+05, improvement:4.141702e-05
# Iteration:  111, loglik:-4.093791e+05, improvement:3.657601e-05
# Iteration:  112, loglik:-4.093791e+05, improvement:3.235304e-05
# Iteration:  113, loglik:-4.093791e+05, improvement:2.865039e-05
# Iteration:  114, loglik:-4.093791e+05, improvement:2.540363e-05
# Iteration:  115, loglik:-4.093791e+05, improvement:2.255174e-05
# Iteration:  116, loglik:-4.093791e+05, improvement:2.003438e-05
# Iteration:  117, loglik:-4.093791e+05, improvement:1.781195e-05
# Iteration:  118, loglik:-4.093791e+05, improvement:1.585390e-05
# Iteration:  119, loglik:-4.093791e+05, improvement:1.411757e-05
# Iteration:  120, loglik:-4.093791e+05, improvement:1.257600e-05
# Iteration:  121, loglik:-4.093791e+05, improvement:1.121836e-05
# Iteration:  122, loglik:-4.093791e+05, improvement:1.000374e-05
# Iteration:  123, loglik:-4.093791e+05, improvement:8.922128e-06
# Iteration:  124, loglik:-4.093791e+05, improvement:7.971306e-06
# Iteration:  125, loglik:-4.093791e+05, improvement:7.110590e-06
# Iteration:  126, loglik:-4.093791e+05, improvement:6.353599e-06
# Iteration:  127, loglik:-4.093791e+05, improvement:5.680195e-06
# Iteration:  128, loglik:-4.093791e+05, improvement:5.072448e-06
# Iteration:  129, loglik:-4.093791e+05, improvement:4.536647e-06
# Iteration:  130, loglik:-4.093791e+05, improvement:4.051253e-06
# Iteration:  131, loglik:-4.093791e+05, improvement:3.627094e-06
# Iteration:  132, loglik:-4.093791e+05, improvement:3.238209e-06
# Iteration:  133, loglik:-4.093791e+05, improvement:2.900662e-06
# Iteration:  134, loglik:-4.093791e+05, improvement:2.590066e-06
# Iteration:  135, loglik:-4.093791e+05, improvement:2.318702e-06
# Iteration:  136, loglik:-4.093791e+05, improvement:2.073823e-06
# Iteration:  137, loglik:-4.093791e+05, improvement:1.862587e-06
# Iteration:  138, loglik:-4.093791e+05, improvement:1.658569e-06
# Iteration:  139, loglik:-4.093791e+05, improvement:1.485285e-06
# Iteration:  140, loglik:-4.093791e+05, improvement:1.326029e-06
# Iteration:  141, loglik:-4.093791e+05, improvement:1.190871e-06
# Iteration:  142, loglik:-4.093791e+05, improvement:1.065433e-06
# Iteration:  143, loglik:-4.093791e+05, improvement:9.532669e-07
# Iteration:  144, loglik:-4.093791e+05, improvement:8.582138e-07
# Iteration:  145, loglik:-4.093791e+05, improvement:7.626950e-07
# Iteration:  146, loglik:-4.093791e+05, improvement:6.793416e-07
# Iteration:  147, loglik:-4.093791e+05, improvement:6.157788e-07
# Iteration:  148, loglik:-4.093791e+05, improvement:5.420879e-07
# Iteration:  149, loglik:-4.093791e+05, improvement:4.946487e-07
# Iteration:  150, loglik:-4.093791e+05, improvement:4.331232e-07
# Iteration:  151, loglik:-4.093791e+05, improvement:3.977329e-07
# Iteration:  152, loglik:-4.093791e+05, improvement:3.498862e-07
# Iteration:  153, loglik:-4.093791e+05, improvement:3.158930e-07
# Iteration:  154, loglik:-4.093791e+05, improvement:2.791639e-07
# Iteration:  155, loglik:-4.093791e+05, improvement:2.494780e-07
# Iteration:  156, loglik:-4.093791e+05, improvement:2.285815e-07
# Iteration:  157, loglik:-4.093791e+05, improvement:2.037268e-07
# Iteration:  158, loglik:-4.093791e+05, improvement:1.781154e-07
# Iteration:  159, loglik:-4.093791e+05, improvement:1.620501e-07
# Iteration:  160, loglik:-4.093791e+05, improvement:1.437147e-07
# Iteration:  161, loglik:-4.093791e+05, improvement:1.312001e-07
# Iteration:  162, loglik:-4.093791e+05, improvement:1.180451e-07
# Iteration:  163, loglik:-4.093791e+05, improvement:1.030858e-07
# Iteration:  164, loglik:-4.093791e+05, improvement:9.086216e-08
# Iteration:  165, loglik:-4.093791e+05, improvement:7.997733e-08
# Iteration:  166, loglik:-4.093791e+05, improvement:7.863855e-08
# Iteration:  167, loglik:-4.093791e+05, improvement:6.711343e-08
# Iteration:  168, loglik:-4.093791e+05, improvement:5.925540e-08
# Iteration:  169, loglik:-4.093791e+05, improvement:5.122274e-08
# Iteration:  170, loglik:-4.093791e+05, improvement:4.877802e-08
# Iteration:  171, loglik:-4.093791e+05, improvement:4.627509e-08
# Iteration:  172, loglik:-4.093791e+05, improvement:3.533205e-08
# Iteration:  173, loglik:-4.093791e+05, improvement:3.463356e-08
# Iteration:  174, loglik:-4.093791e+05, improvement:2.898742e-08
# Iteration:  175, loglik:-4.093791e+05, improvement:3.178138e-08
# Iteration:  176, loglik:-4.093791e+05, improvement:2.497109e-08
# Iteration:  177, loglik:-4.093791e+05, improvement:2.043089e-08
# Iteration:  178, loglik:-4.093791e+05, improvement:2.357410e-08
# Iteration:  179, loglik:-4.093791e+05, improvement:1.635635e-08
# Iteration:  180, loglik:-4.093791e+05, improvement:1.158332e-08
# Iteration:  181, loglik:-4.093791e+05, improvement:1.746230e-08
# Iteration:  182, loglik:-4.093791e+05, improvement:1.431908e-08
# Iteration:  183, loglik:-4.093791e+05, improvement:1.018634e-08
# Iteration:  184, loglik:-4.093791e+05, improvement:9.778887e-09
# Iteration:  185, loglik:-4.093791e+05, improvement:5.937181e-09
# Iteration:  186, loglik:-4.093791e+05, improvement:8.381903e-09
# Iteration:  187, loglik:-4.093791e+05, improvement:5.122274e-09
# Iteration:  188, loglik:-4.093791e+05, improvement:1.082662e-08
# Iteration:  189, loglik:-4.093791e+05, improvement:4.307367e-09
# Iteration:  190, loglik:-4.093791e+05, improvement:6.461050e-09
# Iteration:  191, loglik:-4.093791e+05, improvement:6.693881e-09
# Iteration:  192, loglik:-4.093791e+05, improvement:2.095476e-09
# Iteration:  193, loglik:-4.093791e+05, improvement:4.249159e-09
# Iteration:  194, loglik:-4.093791e+05, improvement:1.688022e-09
# Iteration:  195, loglik:-4.093791e+05, improvement:2.444722e-09
# Iteration:  196, loglik:-4.093791e+05, improvement:4.773028e-09
# Iteration:  197, loglik:-4.093791e+05, improvement:1.979060e-09
# Iteration:  198, loglik:-4.093791e+05, improvement:3.725290e-09
# Iteration:  199, loglik:-4.093791e+05, improvement:1.338776e-09
# The model converged after 199 iterations

# %% [markdown]
# ### Changing output stream with `print_stream`
#
# The `print_formatter` can be instructed to direct the output to another stream,
# such as `sys.stderr` by specifying the `print_stream` keyword argument:

# %%
import sys
model_3d3c = hm.EM_H2MM_C(hm.factory_h2mm_model(3,3), color3,  times3, print_func='diff', print_stream=sys.stderr)
# Out:
# The model converged after 198 iterations

# %% [markdown]
# ### Whats actually happeing
#
# Now that simple options have been described, let's go through what actually is happeing.
#
# Before an optimization begins, `EM_H2MM_C` creates a *formatter* object.
# These are typically a subclass of `Printer`, the default being `StdPrinter`.
# It does so by calling `print_formatter(print_stream, *print_fmt_args, **print_fmt_kwargs)`
#
# > **Note**
# >
# > If `print_formatter` is `None`, then `print_formatter` will be the default
# > formater specified by `optimization_limits.formatter`.
# >
# > If `print_stream` is `None`, it will be the default specified by
# > *calling* `optmiziation_limits.outstream()`, this means that
# > `optmiziation_limits.outstream` should be a callable that takes no
# > arguments. This allows for a "factory" function to be creates so that
# > the stream can be dynamically assigned.
#
# Then optimization begins.
#
# Upon the completion of an iteration of optimization, `EM_H2MM_C` first checks
# if the iteration should be updated based on `print_freq`.
#
# If it is time to update the display, then `EM_H2MM_C` calls `print_func` with the
# cooresponding arguments, and hands the output as the single argument to
# `formatter.update`. The total call look like:
# `formatter.update(print_func(niter, new, current, old, iter_time, total_time, *print_args, **print_kwargs))`
#
# At the end of the optimization `formatter.close()` is called, to ensure any finalization should be conducted.
#
# The default `StdPrinter` has `__init__` signature of `(buffer, keep=False)`. From this you can see how
# specifying `print_stream=sys.stderr` and `print_fmt_kwargs=dict(keep=False)` changes where the output is
# printed and how it is printed respectively.
#
# The `update` method takes the one argument, formats it according to `keep` and then
# sends the formatted output to `print_stream.write(text)`, and the
# calls `print_stream.flush()` to ensure the output is actually displayed.
#
# #### IPyPrinter
#
# Out of the box, `H2MM_C` comes with one other `Printer` class: `IPyPrinter`.
# This class requires [IPython](https://ipython.org/) to be installed, if it is not,
# then this class will not exist.
#
# `IPyPrinter` is initiallized with the following signature: `(handle, keep=False)`
# Where `handle` is a [IPython.display.DisplayHandle](https://ipython.readthedocs.io/en/8.26.0/api/generated/IPython.display.html)
# So the default `sys.stdout` will not work for the `print_stream` argument.
# Instead, you will have to generate a `DisplayHandle` to use `IPyPrinter`
#
# Below see a simple call using `IPyPrinter`.

# %%
from IPython.display import DisplayHandle, clear_output

# %%
model_3d3c = hm.EM_H2MM_C(hm.factory_h2mm_model(3,3), color3,  times3, print_func='all', print_formatter=hm.IPyPrinter, print_stream=DisplayHandle())
# Out:
# The model converged after 198 iterations

# %% [markdown]
# Since it is awkward to create a `DisplayHandle` each time, if you plan to use `IPyPrinter`, I would suggest
# setting `optimization_limits.formatter=IPyPrinter` and `optimization_limits.outstream=lambda:DisplayHandle()`
# at the beginning of your code instead.

# %%
hm.optimization_limits.formatter = hm.IPyPrinter
hm.optimization_limits.outstream = lambda:DisplayHandle()

# %%
model_3d3c = hm.EM_H2MM_C(hm.factory_h2mm_model(3,3), color3,  times3, print_func='all', print_fmt_kwargs=dict(keep=True))
# Out:
# nstate: 3, ndet: 3, nphot: 436084, niter: 0, loglik: -438789.88126171875 converged state: 0x2
# prior:
# 0.3333333333333333, 0.3333333333333333, 0.3333333333333333
# trans:
# 0.9999800000000001, 9.999999999999999e-06, 9.999999999999999e-06
# 9.999999999999999e-06, 0.9999800000000001, 9.999999999999999e-06
# 9.999999999999997e-06, 9.999999999999997e-06, 0.99998
# obs:
# 0.2, 0.6, 0.2
# 0.3333333333333333, 0.3333333333333333, 0.3333333333333333
# 0.42857142857142855, 0.14285714285714285, 0.42857142857142855
#
# Iteration time:0.117147, Total:0.117147
# nstate: 3, ndet: 3, nphot: 436084, niter: 1, loglik: -420399.1249372309 converged state: 0x3
# prior:
# 0.1117208707845065, 0.2311783028752123, 0.6571008263402811
# trans:
# 0.9999331696914695, 2.1507726405781882e-05, 4.532258212485634e-05
# 4.90099423170154e-06, 0.9999761060427823, 1.899296298592765e-05
# 2.3715976119226347e-06, 4.449513692035169e-06, 0.9999931788886961
# obs:
# 0.1675383924040133, 0.5067016197975466, 0.3257599877984402
# 0.21132635485941328, 0.30405173296135757, 0.4846219121792292
# 0.4584290628671556, 0.09495409346181162, 0.4466168436710327
#
# Iteration time:0.227356, Total:0.344503
# nstate: 3, ndet: 3, nphot: 436084, niter: 2, loglik: -417249.50409145467 converged state: 0x3
# prior:
# 0.09091142084379221, 0.22007069067819193, 0.6890178884780159
# trans:
# 0.9999144400245912, 2.935660704994367e-05, 5.620336835880589e-05
# 3.5414372397300418e-06, 0.9999804622729409, 1.5996289819362496e-05
# 1.8202533298936034e-06, 4.487103219954353e-06, 0.9999936926434501
# obs:
# 0.1534465826990262, 0.4770665762187906, 0.36948684108218327
# 0.16415044861942513, 0.2801694055966424, 0.5556801457839325
# 0.49655981435983815, 0.08523078052384118, 0.41820940511632076
#
# Iteration time:0.22521, Total:0.569713
# nstate: 3, ndet: 3, nphot: 436084, niter: 3, loglik: -416816.01318494114 converged state: 0x3
# prior:
# 0.09159788880100972, 0.20977893868360642, 0.6986231725153838
# trans:
# 0.9999093631219519, 3.2635913746483285e-05, 5.800096430158153e-05
# 3.297928489007935e-06, 0.9999807254752553, 1.5976596255699993e-05
# 1.8257445805909652e-06, 5.32450326722673e-06, 0.9999928497521522
# obs:
# 0.15501465610599513, 0.46516745477675453, 0.3798178891172503
# 0.1560630734896388, 0.26407284926271435, 0.5798640772476469
# 0.5103988428088005, 0.08459539340219153, 0.405005763789008
#
# Iteration time:0.148642, Total:0.718355
# nstate: 3, ndet: 3, nphot: 436084, niter: 4, loglik: -416669.66991672915 converged state: 0x3
# prior:
# 0.09880655909407769, 0.19795231279178477, 0.7032411281141375
# trans:
# 0.9999112455525201, 3.3407835993866235e-05, 5.534661148601384e-05
# 3.4701038288956217e-06, 0.9999794187761594, 1.711112001178184e-05
# 1.915163431137583e-06, 6.194681942488657e-06, 0.9999918901546263
# obs:
# 0.15668016549474756, 0.4588622330652135, 0.38445760144003893
# 0.1554081836323099, 0.2550192659626375, 0.5895725504050526
# 0.51619912099917, 0.08437750808586773, 0.39942337091496233
#
# Iteration time:0.135343, Total:0.853698
# nstate: 3, ndet: 3, nphot: 436084, niter: 5, loglik: -416571.3552499313 converged state: 0x3
# prior:
# 0.10815050812009774, 0.18696790046497336, 0.7048815914149289
# trans:
# 0.9999154800079714, 3.3397193427851656e-05, 5.112279860072906e-05
# 3.7984177088680904e-06, 0.9999777135494082, 1.8488032882892955e-05
# 1.9997018348441833e-06, 6.97725444630198e-06, 0.9999910230437189
# obs:
# 0.15672053100815037, 0.45367716813364733, 0.38960230085820236
# 0.15601724155556318, 0.24877575471981622, 0.5952070037246207
# 0.5197180771694859, 0.084008952281813, 0.39627297054870114
#
# Iteration time:0.158004, Total:1.011702
# nstate: 3, ndet: 3, nphot: 436084, niter: 6, loglik: -416486.7511525023 converged state: 0x3
# prior:
# 0.11801555761578136, 0.17674035701948812, 0.7052440853647306
# trans:
# 0.9999204691004234, 3.308327919708611e-05, 4.6447620379472245e-05
# 4.21518764588575e-06, 0.9999758910815926, 1.9893730761559755e-05
# 2.06497940301504e-06, 7.668846607352318e-06, 0.9999902661739896
# obs:
# 0.15543613038784612, 0.44805387803172525, 0.3965099915804286
# 0.15690048445427388, 0.2434157936819413, 0.5996837218637848
# 0.5223655621688789, 0.08363832319456285, 0.3939961146365583
#
# Iteration time:0.114943, Total:1.126645
# nstate: 3, ndet: 3, nphot: 436084, niter: 7, loglik: -416403.04389008647 converged state: 0x3
# prior:
# 0.12771599359252392, 0.16690788332920908, 0.705376123078267
# trans:
# 0.9999258362840913, 3.2495811426867354e-05, 4.1667904481791214e-05
# 4.707539625857074e-06, 0.9999739960267714, 2.129643360279951e-05
# 2.1130941388932096e-06, 8.284755657816704e-06, 0.9999896021502033
# obs:
# 0.15316934105245866, 0.4415510803609983, 0.4052795785865431
# 0.15800097542752053, 0.23808154366175135, 0.6039174809107282
# 0.5245930497580293, 0.08333603150902152, 0.39207091873294914
#
# Iteration time:0.127831, Total:1.254476
# nstate: 3, ndet: 3, nphot: 436084, niter: 8, loglik: -416311.62037311576 converged state: 0x3
# prior:
# 0.13696190913274847, 0.15726757206982225, 0.7057705187974292
# trans:
# 0.9999315110210555, 3.156017723890164e-05, 3.6928801705601776e-05
# 5.2773775220943875e-06, 0.999972003489566, 2.271913291176919e-05
# 2.149576855273591e-06, 8.842852328507192e-06, 0.9999890075708162
# obs:
# 0.1502662983527219, 0.4340724552422735, 0.41566124640500457
# 0.15943596569671312, 0.23230296581558751, 0.6082610684876995
# 0.5266150813608369, 0.08311487979880709, 0.390270038840356
#
# Iteration time:0.141788, Total:1.396264
# nstate: 3, ndet: 3, nphot: 436084, niter: 9, loglik: -416205.50512884517 converged state: 0x3
# prior:
# 0.1456476224144889, 0.14777875068896903, 0.706573626896542
# trans:
# 0.999937407283046, 3.0231047755730593e-05, 3.236166919821796e-05
# 5.928895156299726e-06, 0.9999698638427418, 2.4207262101972295e-05
# 2.179868364040369e-06, 9.361689657450501e-06, 0.9999884584419785
# obs:
# 0.14710408937476974, 0.4256270526472251, 0.42726885797800523
# 0.1613621403163703, 0.22576533163887716, 0.6128725280447526
# 0.5285721750783955, 0.08296831109962016, 0.38845951382198435
#
# Iteration time:0.109357, Total:1.505621
# nstate: 3, ndet: 3, nphot: 436084, niter: 10, loglik: -416078.5463625853 converged state: 0x3
# prior:
# 0.15377341379288514, 0.13850395385002695, 0.707722632357088
# trans:
# 0.9999433653501936, 2.8529673055064614e-05, 2.810497675141041e-05
# 6.663067089105919e-06, 0.9999675183086887, 2.5818624222265775e-05
# 2.2086543584743786e-06, 9.86122583011018e-06, 0.9999879301198114
# obs:
# 0.14400554636940957, 0.41628116444906155, 0.43971328918152885
# 0.16396801508224387, 0.21822381472857907, 0.6178081701891771
# 0.5305772508606255, 0.08288529225172558, 0.3865374568876489
#
# Iteration time:0.106598, Total:1.612219
# nstate: 3, ndet: 3, nphot: 436084, niter: 11, loglik: -415925.608351338 converged state: 0x3
# prior:
# 0.1614264686363483, 0.12953718495826147, 0.7090363464053901
# trans:
# 0.999949176707421, 2.653988644476924e-05, 2.4283406134204437e-05
# 7.471399676632058e-06, 0.9999649122631988, 2.7616337124542154e-05
# 2.2404011941389537e-06, 1.0363649275076542e-05, 0.9999873959495308
# obs:
# 0.1412257721852876, 0.4061599130664314, 0.4526143147482811
# 0.1674776061297123, 0.20948944076256773, 0.62303295310772
# 0.5327351297642127, 0.08285589093116749, 0.3844089793046198
#
# Iteration time:0.136126, Total:1.748345
# nstate: 3, ndet: 3, nphot: 436084, niter: 12, loglik: -415744.74730132456 converged state: 0x3
# prior:
# 0.1687627900508592, 0.1209664729543556, 0.7102707369947852
# trans:
# 0.9999546252628049, 2.4388026685108856e-05, 2.098671051005662e-05
# 8.327523833041007e-06, 0.9999620157324898, 2.9656743677220173e-05
# 2.2800586734543827e-06, 1.089390619188085e-05, 0.9999868260351346
# obs:
# 0.1390082030688641, 0.3955316330768197, 0.46546016385431616
# 0.1721188980206785, 0.1994800682392391, 0.6284010337400825
# 0.5351512069499333, 0.08287305970006749, 0.38197573334999924
#
# Iteration time:0.117771, Total:1.866116
# nstate: 3, ndet: 3, nphot: 436084, niter: 13, loglik: -415540.08300131076 converged state: 0x3
# prior:
# 0.17596212835094147, 0.11288187434984924, 0.7111559972992094
# trans:
# 0.9999595049721061, 2.2228732281744677e-05, 1.8266295612146745e-05
# 9.176136527944649e-06, 0.9999588629860998, 3.1960877372290114e-05
# 2.3328618291702135e-06, 1.1480067666837687e-05, 0.999986187070504
# obs:
# 0.13761375252561925, 0.3848518803291084, 0.47753436714527236
# 0.17802350190160474, 0.1883641631059408, 0.6336123349924544
# 0.5379280424552227, 0.08293229640918444, 0.3791396611355927
#
# Iteration time:0.117065, Total:1.983181
# nstate: 3, ndet: 3, nphot: 436084, niter: 14, loglik: -415318.8885941473 converged state: 0x3
# prior:
# 0.18318072819867626, 0.1053739228362762, 0.7114453489650475
# trans:
# 0.9999636710874935, 2.0211369492104458e-05, 1.611754301439906e-05
# 9.944756723062687e-06, 0.9999555612629416, 3.4493980335331024e-05
# 2.4036256677099553e-06, 1.2151224885506575e-05, 0.9999854451494467
# obs:
# 0.13717456804760875, 0.3745545381513441, 0.4882708938010472
# 0.18518506261397794, 0.1765277193164863, 0.6382872180695358
# 0.5411434408454495, 0.08302927335592933, 0.37582728579862107
#
# Iteration time:0.117408, Total:2.100589
# nstate: 3, ndet: 3, nphot: 436084, niter: 15, loglik: -415086.6104004391 converged state: 0x3
# prior:
# 0.1905172852809264, 0.09850158466280218, 0.7109811300562714
# trans:
# 0.9999670887283184, 1.8433204048454983e-05, 1.4478067633109375e-05
# 1.0570985510057296e-05, 0.9999522579047349, 3.717110975512652e-05
# 2.4966475287963647e-06, 1.2932831455464824e-05, 0.9999845705210157
# obs:
# 0.1376001609471727, 0.36495854621713425, 0.497441292835693
# 0.19353006333029651, 0.16438803472915306, 0.6420819019405505
# 0.5448419869777341, 0.08316259240146569, 0.37199542062080015
#
# Iteration time:0.137536, Total:2.238125
# nstate: 3, ndet: 3, nphot: 436084, niter: 16, loglik: -414845.1096463682 converged state: 0x3
# prior:
# 0.1979959575362594, 0.09228016782378631, 0.7097238746399542
# trans:
# 0.9999698146965069, 1.6929256872738754e-05, 1.3256046620367138e-05
# 1.1017105412996387e-05, 0.9999491111028108, 3.987179177616162e-05
# 2.615335839196299e-06, 1.3844419868286096e-05, 0.9999835402442926
# obs:
# 0.13858015471665122, 0.3562050040603574, 0.5052148412229913
# 0.20306640286473615, 0.15227849696241336, 0.6446551001728505
# 0.549046567639879, 0.08333861699103813, 0.36761481536908286
#
# Iteration time:0.126528, Total:2.364653
# nstate: 3, ndet: 3, nphot: 436084, niter: 17, loglik: -414596.4341028921 converged state: 0x3
# prior:
# 0.20555371450593563, 0.0867068121533973, 0.7077394733406671
# trans:
# 0.9999719375449758, 1.569752369886291e-05, 1.236493132549506e-05
# 1.1265219214199476e-05, 0.9999463014816812, 4.24332991045921e-05
# 2.761150281741175e-06, 1.4902290172525792e-05, 0.9999823365595457
# obs:
# 0.13983460820110233, 0.348379754510216, 0.5117856372886816
# 0.2138065088871093, 0.14055002109985035, 0.6456434700130405
# 0.5537829379200843, 0.08357257928104704, 0.3626444827988687
#
# Iteration time:0.139738, Total:2.504391
# nstate: 3, ndet: 3, nphot: 436084, niter: 18, loglik: -414343.47991491825 converged state: 0x3
# prior:
# 0.21306101620416562, 0.08178965820350444, 0.70514932559233
# trans:
# 0.999973557114162, 1.471317942101382e-05, 1.1729706416840489e-05
# 1.1314890473582086e-05, 0.9999440145101886, 4.467059933771973e-05
# 2.933273251760628e-06, 1.6119944722145195e-05, 0.9999809467820261
# obs:
# 0.1411813731351148, 0.34150127379131856, 0.5173173530735666
# 0.22565760325470557, 0.1296304758717466, 0.6447119208735478
# 0.5590813603891573, 0.08387848056494213, 0.3570401590459006
#
# Iteration time:0.117851, Total:2.622242
# nstate: 3, ndet: 3, nphot: 436084, niter: 19, loglik: -414088.0611717225 converged state: 0x3
# prior:
# 0.22034938789982145, 0.07756710028789099, 0.7020835118122875
# trans:
# 0.9999747718471239, 1.3943820946680822e-05, 1.1284331929553778e-05
# 1.118647131319191e-05, 0.9999423888233889, 4.642470529785908e-05
# 3.129140709769844e-06, 1.7505726634426988e-05, 0.9999793651326557
# obs:
# 0.14245648280438988, 0.33548447307672696, 0.5220590441188832
# 0.2384585975516283, 0.11986391329536002, 0.6416774891530116
# 0.5649557297763973, 0.08425763714596998, 0.3507866330776327
#
# Iteration time:0.10935, Total:2.731592
# nstate: 3, ndet: 3, nphot: 436084, niter: 20, loglik: -413831.941608311 converged state: 0x3
# prior:
# 0.22727135829699951, 0.07409450408811166, 0.6986341376148888
# trans:
# 0.9999756697492006, 1.335780763426376e-05, 1.0972443165131246e-05
# 1.0914218743236124e-05, 0.9999414928576533, 4.759292360340551e-05
# 3.345520134043514e-06, 1.906229274121962e-05, 0.9999775921871247
# obs:
# 0.14356412931742, 0.3302192087937145, 0.5262166618888655
# 0.2519568647830004, 0.11144072030230971, 0.6366024149146899
# 0.5714002449356471, 0.08470192950362473, 0.343897825560728
#
# Iteration time:0.134092, Total:2.865684
# nstate: 3, ndet: 3, nphot: 436084, niter: 21, loglik: -413578.6836731175 converged state: 0x3
# prior:
# 0.23370266108182866, 0.07143472506594081, 0.6948626138522305
# trans:
# 0.9999763176738514, 1.2931447745442231e-05, 1.075087840312081e-05
# 1.0535711412019114e-05, 0.999941337851557, 4.812643703099994e-05
# 3.579127636512787e-06, 2.078792168145669e-05, 0.999975632950682
# obs:
# 0.1445007071693351, 0.32570230190177385, 0.5297969909288912
# 0.26574079695405234, 0.1044597788874369, 0.6297994241585108
# 0.5784004801542658, 0.08519901624657393, 0.3364005035991602
#
# Iteration time:0.123818, Total:2.989502
# nstate: 3, ndet: 3, nphot: 436084, niter: 22, loglik: -413331.11147511075 converged state: 0x3
# prior:
# 0.23953287974664583, 0.06965145484918983, 0.6908156654041643
# trans:
# 0.9999767633421214, 1.2649694776401752e-05, 1.05869631021909e-05
# 1.0091962447143347e-05, 0.9999418716389578, 4.8036398595219506e-05
# 3.8263735094041235e-06, 2.2676725033751513e-05, 0.9999734969014569
# obs:
# 0.14528654314425446, 0.32194073875270285, 0.5327727181030428
# 0.2793506973038291, 0.09891817523003138, 0.6217311274661395
# 0.5859405822080586, 0.08572706689579543, 0.32833235089614604
#
# Iteration time:0.106777, Total:3.096279
# nstate: 3, ndet: 3, nphot: 436084, niter: 23, loglik: -413089.2419059827 converged state: 0x3
# prior:
# 0.24470839154420404, 0.0687955357715516, 0.6864960726842443
# trans:
# 0.9999770515269573, 1.2495299602388588e-05, 1.0453173440365747e-05
# 9.621406542991137e-06, 0.999942985120104, 4.739347335304142e-05
# 4.083517290532745e-06, 2.471866187235042e-05, 0.9999711978208371
# obs:
# 0.14592728819586598, 0.3188469163524328, 0.5352257954517012
# 0.29245846264695924, 0.09468555951806852, 0.6128559778349723
# 0.594018072010337, 0.08625800497922974, 0.3197239230104334
#
# Iteration time:0.135864, Total:3.232143
# nstate: 3, ndet: 3, nphot: 436084, niter: 24, loglik: -412851.3911096398 converged state: 0x3
# prior:
# 0.24925175600420352, 0.06890495072220189, 0.6818432932735945
# trans:
# 0.9999772257218386, 1.244770018349169e-05, 1.0326577978029514e-05
# 9.15407368247615e-06, 0.9999445461619146, 4.6299764402825514e-05
# 4.3476659528080415e-06, 2.6900716003336875e-05, 0.9999687516180439
# obs:
# 0.1464206730956506, 0.31628619886473514, 0.5372931280396143
# 0.30489441530725137, 0.09155826237298022, 0.6035473223197684
# 0.6026457839095576, 0.0867672295730771, 0.31058698651736527
#
# Iteration time:0.109467, Total:3.34161
# nstate: 3, ndet: 3, nphot: 436084, niter: 25, loglik: -412615.74962050037 converged state: 0x3
# prior:
# 0.2532325370323972, 0.07001840694974405, 0.6767490560178588
# trans:
# 0.9999773231010819, 1.2486925713437309e-05, 1.0189973204722932e-05
# 8.709855918499204e-06, 0.9999464290251542, 4.486111892732115e-05
# 4.617034593128464e-06, 2.9208064906433353e-05, 0.9999661749005004
# obs:
# 0.14677377528447383, 0.3141291029258333, 0.5390971217896929
# 0.3165944646880797, 0.0893163871817923, 0.5940891481301279
# 0.6118413536745845, 0.08723539183534638, 0.3009232544900693
#
# Iteration time:0.12242, Total:3.46403
# nstate: 3, ndet: 3, nphot: 436084, niter: 26, loglik: -412381.05046227115 converged state: 0x3
# prior:
# 0.25673385763431184, 0.07218881433475596, 0.6710773280309322
# trans:
# 0.9999773715394218, 1.2596313020601876e-05, 1.0032147557590781e-05
# 8.300268546863104e-06, 0.999948527818757, 4.317191269615655e-05
# 4.8906794248088076e-06, 3.1624047410442374e-05, 0.9999634852731648
# obs:
# 0.14700873545712942, 0.31227988394058304, 0.5407113806022875
# 0.32754912038168466, 0.08775988256099092, 0.5846909970573243
# 0.6216247038091299, 0.08764815174338249, 0.2907271444474877
#
# Iteration time:0.134405, Total:3.598435
# nstate: 3, ndet: 3, nphot: 436084, niter: 27, loglik: -412146.5753064607 converged state: 0x3
# prior:
# 0.25983587222410126, 0.07549181830221029, 0.6646723094736884
# trans:
# 0.9999773902983807, 1.2762937006216167e-05, 9.846764613032168e-06
# 7.931385318946081e-06, 0.9999507575999903, 4.131101469078299e-05
# 5.168200789199386e-06, 3.4129428020150245e-05, 0.9999607023711906
# obs:
# 0.14715331862039988, 0.31066923432265797, 0.5421774470569422
# 0.3377791179003117, 0.08671974103886071, 0.5755011410608276
# 0.6320143589570127, 0.08799618387680712, 0.2799894571661801
#
# Iteration time:0.122961, Total:3.721396
# nstate: 3, ndet: 3, nphot: 436084, niter: 28, loglik: -411911.93947217 converged state: 0x3
# prior:
# 0.2626091590188099, 0.08002833676504824, 0.6573625042161418
# trans:
# 0.9999773922731497, 1.2976852174315848e-05, 9.630874675954305e-06
# 7.605954545035052e-06, 0.9999530517697329, 3.934227572217092e-05
# 5.449592764877747e-06, 3.670133737170754e-05, 0.9999578490698634
# obs:
# 0.14723219417895023, 0.30923995910003094, 0.543527846721019
# 0.347329442493068, 0.08605694141686665, 0.5666136160900653
# 0.6430224082912417, 0.0882763802305752, 0.26870121147818316
#
# Iteration time:0.101839, Total:3.823235
# nstate: 3, ndet: 3, nphot: 436084, niter: 29, loglik: -411677.0679808318 converged state: 0x3
# prior:
# 0.265110564713115, 0.08592278352339985, 0.648966651763485
# trans:
# 0.9999773858663387, 1.3230427964351937e-05, 9.383705696987161e-06
# 7.324663120015282e-06, 0.9999553602458157, 3.731509106423761e-05
# 5.7351364166296965e-06, 3.9311656009294985e-05, 0.999954953207574
# obs:
# 0.14726465512721645, 0.30794134756057173, 0.5447939973122118
# 0.35626116079873543, 0.08566068976700073, 0.5580781494342638
# 0.6546515577669698, 0.08849099729317286, 0.25685744493985735
#
# Iteration time:0.135258, Total:3.958493
# nstate: 3, ndet: 3, nphot: 436084, niter: 30, loglik: -411442.6378319967 converged state: 0x3
# prior:
# 0.2673801047059268, 0.09331775374357072, 0.6393021415505025
# trans:
# 0.9999773761849087, 1.3517788045105877e-05, 9.106027046244488e-06
# 7.0870880792384355e-06, 0.9999576461145123, 3.526679740856628e-05
# 6.025086908945739e-06, 4.192498701273437e-05, 0.9999520499260783
# obs:
# 0.1472655546600178, 0.3067297831216768, 0.5460046622183055
# 0.364628901648724, 0.08544918087494138, 0.5499219174763346
# 0.6668843243372233, 0.08864140472662732, 0.24447427093614937
#
# Iteration time:0.113381, Total:4.071874
# nstate: 3, ndet: 3, nphot: 436084, niter: 31, loglik: -411210.5756765433 converged state: 0x3
# prior:
# 0.2694385177000282, 0.10236232030049368, 0.628199161999478
# trans:
# 0.9999773658267529, 1.383395343515146e-05, 8.800219811923546e-06
# 6.892251080173752e-06, 0.999959879730262, 3.3228018657798445e-05
# 6.319029127998796e-06, 4.449742241578164e-05, 0.9999491835484562
# obs:
# 0.14724639332295247, 0.3055725088026379, 0.5471810978744096
# 0.37246149114156296, 0.0853677894798996, 0.5421707193785374
# 0.6796615543934966, 0.08872116847128542, 0.23161727713521799
#
# Iteration time:0.118835, Total:4.190709
# nstate: 3, ndet: 3, nphot: 436084, niter: 32, loglik: -410983.9732711039 converged state: 0x3
# prior:
# 0.2712864359790255, 0.11319273449710789, 0.6155208295238667
# trans:
# 0.9999773555526869, 1.4173945739114897e-05, 8.47050157401198e-06
# 6.738676844541429e-06, 0.9999620342011525, 3.1227122002908065e-05
# 6.6151489772987465e-06, 4.697743986045786e-05, 0.9999464074111623
# obs:
# 0.1472158457371509, 0.30445150617294753, 0.5483326480899016
# 0.37976519098561706, 0.08538043570059135, 0.5348543733137915
# 0.6928677286320283, 0.08871756773286596, 0.21841470363510568
#
# Iteration time:0.142615, Total:4.333324
# nstate: 3, ndet: 3, nphot: 436084, niter: 33, loglik: -410766.46738142456 converged state: 0x3
# prior:
# 0.2729061889393514, 0.12590898811995493, 0.6011848229406936
# trans:
# 0.9999773450326768, 1.4532380353065977e-05, 8.122586970089515e-06
# 6.6243202319944815e-06, 0.9999640848098207, 2.9290869947226282e-05
# 6.909813427076085e-06, 4.930887067631464e-05, 0.9999437813158966
# obs:
# 0.1471800343079465, 0.3033633441776668, 0.5494566215143867
# 0.38653948076086675, 0.08546023195141783, 0.5280002872877155
# 0.7063353787947154, 0.08861887400759196, 0.20504574719769256
#
# Iteration time:0.105307, Total:4.438631
# nstate: 3, ndet: 3, nphot: 436084, niter: 34, loglik: -410561.488194451 converged state: 0x3
# prior:
# 0.2742670678356176, 0.14055073983346505, 0.5851821923309173
# trans:
# 0.999977333578412, 1.490352050169582e-05, 7.762901086410247e-06
# 6.546560023082775e-06, 0.9999660109189775, 2.7442520999432655e-05
# 7.1976967571819195e-06, 5.1435666470197814e-05, 0.9999413666367726
# obs:
# 0.1471427911851969, 0.3023145657737883, 0.5505426430410149
# 0.392788778443533, 0.0855854429480416, 0.5216257786084254
# 0.7198647081926118, 0.08841867842017441, 0.1917166133872138
#
# Iteration time:0.11734, Total:4.555971
# nstate: 3, ndet: 3, nphot: 436084, niter: 35, loglik: -410371.7297278567 converged state: 0x3
# prior:
# 0.2753348726087611, 0.15707550200215983, 0.5675896253890791
# trans:
# 0.9999773206313399, 1.5281502955405115e-05, 7.39786570464653e-06
# 6.5022242088835535e-06, 0.9999677982191634, 2.5699556627757473e-05
# 7.4724510433522094e-06, 5.3308054353570295e-05, 0.9999392194946031
# obs:
# 0.14710601557250225, 0.30131551073109253, 0.5515784736964052
# 0.39852604873056885, 0.08573845815820853, 0.5157354931112226
# 0.7332495519733305, 0.08811711545401843, 0.17863333257265113
#
# Iteration time:0.146977, Total:4.702948
# nstate: 3, ndet: 3, nphot: 436084, niter: 36, loglik: -410199.27737449156 converged state: 0x3
# prior:
# 0.2760829734136503, 0.17534264898976842, 0.5485743775965812
# trans:
# 0.9999773058807394, 1.5660583426890725e-05, 7.0335358336432025e-06
# 6.487781208043594e-06, 0.9999694395114255, 2.4072707366494978e-05
# 7.727451369669264e-06, 5.488703106511546e-05, 0.9999373855175652
# obs:
# 0.14707021928828298, 0.30037552984807175, 0.5525542508636453
# 0.40376615354284207, 0.08590527089215419, 0.5103285755650038
# 0.7462864605262711, 0.08772069842615501, 0.1659928410475739
#
# Iteration time:0.122192, Total:4.82514
# nstate: 3, ndet: 3, nphot: 436084, niter: 37, loglik: -410046.1280301779 converged state: 0x3
# prior:
# 0.2764983870134293, 0.1951043905097918, 0.5283972224767788
# trans:
# 0.9999772891134473, 1.6035308891836413e-05, 6.675577660856221e-06
# 6.499642490354579e-06, 0.9999709325892684, 2.256776824130122e-05
# 7.956026193777192e-06, 5.614495266659642e-05, 0.9999358990211397
# obs:
# 0.14703507259277565, 0.2995018556079158, 0.5534630717993085
# 0.4085147005301388, 0.08607543885500288, 0.5054098606148584
# 0.7587532018364525, 0.08724085077876118, 0.1540059473847864
#
# Iteration time:0.120307, Total:4.945447
# nstate: 3, ndet: 3, nphot: 436084, niter: 38, loglik: -409913.9624570825 converged state: 0x3
# prior:
# 0.27658062931734, 0.21600375001999422, 0.5074156206626659
# trans:
# 0.9999772700919303, 1.6400619915816863e-05, 6.329288153796225e-06
# 6.534189971204875e-06, 0.999972277100625, 2.118870940385397e-05
# 8.151615339432324e-06, 5.706614067889548e-05, 0.9999347822439817
# obs:
# 0.14699962326467608, 0.2987012009921958, 0.5542991757431281
# 0.4127717999480751, 0.08624187215992977, 0.5009863278919952
# 0.770405635756263, 0.08669337864254759, 0.14290098560118947
#
# Iteration time:0.156155, Total:5.101602
# nstate: 3, ndet: 3, nphot: 436084, niter: 39, loglik: -409803.2127354159 converged state: 0x3
# prior:
# 0.27634196540355715, 0.2375883597657747, 0.48606967483066804
# trans:
# 0.9999772486425133, 1.6752112064938927e-05, 5.999245421904105e-06
# 6.587599001200101e-06, 0.999973474266122, 1.993813487677832e-05
# 8.30868614565879e-06, 5.7650276903816864e-05, 0.9999340410369505
# obs:
# 0.1469624412278928, 0.29797934479953453, 0.5550582139725727
# 0.41654858825416924, 0.08640036865563647, 0.49705104309019427
# 0.7810336548522029, 0.08609716810148971, 0.13286917704630738
#
# Iteration time:0.12272, Total:5.224322
# nstate: 3, ndet: 3, nphot: 436084, niter: 40, loglik: -409712.71341159707 converged state: 0x3
# prior:
# 0.2758138497727169, 0.2593523641015097, 0.46483378612577353
# trans:
# 0.9999772247467009, 1.708647103661725e-05, 5.688782262470747e-06
# 6.6558839762225354e-06, 0.9999745287655767, 1.8815350447202672e-05
# 8.424020541596631e-06, 5.791516694689806e-05, 0.9999336608125116
# obs:
# 0.1469221407686681, 0.29733798560227265, 0.5557398736290593
# 0.41987233003311486, 0.08654879508275427, 0.4935788748841309
# 0.7905159473297899, 0.08547150334547526, 0.12401254932473484
#
# Iteration time:0.116447, Total:5.340769
# nstate: 3, ndet: 3, nphot: 436084, niter: 41, loglik: -409640.1662656666 converged state: 0x3
# prior:
# 0.27504893094422644, 0.28079895463775206, 0.44415211441802155
# trans:
# 0.9999771984420183, 1.7401713699993942e-05, 5.399844281830981e-06
# 6.735163721454865e-06, 0.999975449391305, 1.781544497355722e-05
# 8.497306790360535e-06, 5.78951249179519e-05, 0.9999336075682917
# obs:
# 0.14687801113751492, 0.29677380609803394, 0.5563481827644512
# 0.42278026334864893, 0.08668596032265435, 0.49053377632869666
# 0.7988246919238073, 0.0848351766663085, 0.11634013140988402
#
# Iteration time:0.130872, Total:5.471641
# nstate: 3, ndet: 3, nphot: 436084, niter: 42, loglik: -409582.8042297526 converged state: 0x3
# prior:
# 0.27411289678479056, 0.3014975498784082, 0.4243895533368011
# trans:
# 0.9999771697077697, 1.769705287274827e-05, 5.1332393575841535e-06
# 6.821917145661477e-06, 0.9999762479296287, 1.693015322571917e-05
# 8.53080976849458e-06, 5.7635255644957365e-05, 0.9999338339345866
# obs:
# 0.1468302079975396, 0.2962804561618785, 0.556889335840582
# 0.425313385300186, 0.08681099033748033, 0.48787562436233367
# 0.8060004839781963, 0.08420614988058304, 0.10979336614122058
#
# Iteration time:0.12403, Total:5.595671
# nstate: 3, ndet: 3, nphot: 436084, niter: 43, loglik: -409537.8768664019 converged state: 0x3
# prior:
# 0.2730725260648632, 0.32111644693865093, 0.4058110269964859
# trans:
# 0.9999771384818905, 1.7972555455264778e-05, 4.888962654241264e-06
# 6.913125891507497e-06, 0.9999769375405935, 1.614933351500921e-05
# 8.528612632234563e-06, 5.718482967659247e-05, 0.9999342865576911
# obs:
# 0.14677949350317523, 0.2958507280724932, 0.5573697784243316
# 0.42751269441229056, 0.0869233127384349, 0.4855639928492746
# 0.8121243225502608, 0.0836002653870187, 0.10427541206272062
#
# Iteration time:0.116091, Total:5.711762
# nstate: 3, ndet: 3, nphot: 436084, niter: 44, loglik: -409502.9023877471 converged state: 0x3
# prior:
# 0.27198650859177853, 0.3394302213719899, 0.38858327003623155
# trans:
# 0.9999771047484781, 1.8228805064283232e-05, 4.666446457640507e-06
# 7.006308127233061e-06, 0.9999775314489189, 1.5462242953864623e-05
# 8.495842144320288e-06, 5.659205241936466e-05, 0.9999349121054364
# obs:
# 0.1467268412875672, 0.29547774835581786, 0.557795410356615
# 0.4294173405427401, 0.08702281473165585, 0.483559844725604
# 0.8172977761013612, 0.08302983701876206, 0.0996723868798768
#
# Iteration time:0.129135, Total:5.840897
# nstate: 3, ndet: 3, nphot: 436084, niter: 45, loglik: -409475.76426451845 converged state: 0x3
# prior:
# 0.27090110964133557, 0.356310687950366, 0.37278820240829835
# trans:
# 0.9999770686085401, 1.846665846680251e-05, 4.464732993075151e-06
# 7.0994876853740875e-06, 0.9999780421536723, 1.4858358642400345e-05
# 8.43804280382775e-06, 5.590076484364128e-05, 0.9999356611923524
# obs:
# 0.1466731583604237, 0.2951553090426037, 0.5581715325969727
# 0.4310637647520763, 0.08710988604498064, 0.481826349202943
# 0.8216307618444736, 0.08250300759560128, 0.09586623055992517
#
# Iteration time:0.126407, Total:5.967304
# nstate: 3, ndet: 3, nphot: 436084, niter: 46, loglik: -409454.7257172793 converged state: 0x3
# prior:
# 0.26984964593672583, 0.3717099770409408, 0.35844037702233345
# trans:
# 0.9999770303027434, 1.868709296143373e-05, 4.2826042951753726e-06
# 7.191135758754655e-06, 0.9999784810437192, 1.4327820522003251e-05
# 8.360717909323079e-06, 5.514875036646733e-05, 0.9999364905317243
# obs:
# 0.14661917976498132, 0.29487780308458283, 0.5585030171504358
# 0.43248522973910036, 0.0871853286154513, 0.4803294416454483
# 0.8252334502524673, 0.08202395858430164, 0.09274259116323105
#
# Iteration time:0.12002, Total:6.087324
# nstate: 3, ndet: 3, nphot: 436084, niter: 47, loglik: -409438.4013394681 converged state: 0x3
# prior:
# 0.268854005680997, 0.3856413535642266, 0.3455046407547764
# trans:
# 0.9999769901951867, 1.889111671899542e-05, 4.118688094226541e-06
# 7.28010454697456e-06, 0.9999788582501783, 1.3861645274629851e-05
# 8.269011783950838e-06, 5.436715992094131e-05, 0.9999373638282951
# obs:
# 0.14656546967312128, 0.29464010085922043, 0.5587944294676582
# 0.4337116074679277, 0.08725020956752796, 0.47903818296454437
# 0.8282107009938655, 0.08159364565207837, 0.09019565335405612
#
# Iteration time:0.139438, Total:6.226762
# nstate: 3, ndet: 3, nphot: 436084, niter: 48, loglik: -409425.7081490975 converged state: 0x3
# prior:
# 0.2679269364685597, 0.3981610966967709, 0.33391196683466945
# trans:
# 0.9999769487375862, 1.9079719715075566e-05, 3.971542698761077e-06
# 7.365562436724511e-06, 0.9999791826318766, 1.3451805686688613e-05
# 8.167510634784988e-06, 5.3580661504187316e-05, 0.9999382518278611
# obs:
# 0.14651245968264037, 0.2944374736801643, 0.5590500666371953
# 0.43476938741249155, 0.0873057166255717, 0.4779248959619368
# 0.8306586064130659, 0.08121070782326809, 0.08813068576366603
#
# Iteration time:0.120762, Total:6.347524
# nstate: 3, ndet: 3, nphot: 436084, niter: 49, loglik: -409415.81079647224 converged state: 0x3
# prior:
# 0.2670743912176266, 0.4093531424396637, 0.32357246634270964
# trans:
# 0.9999769064285251, 1.9253850735253257e-05, 3.839720739662522e-06
# 7.4469354271610376e-06, 0.9999794618396203, 1.3091224952535244e-05
# 8.060142238164137e-06, 5.280802340287496e-05, 0.999939131834359
# obs:
# 0.14646048972464895, 0.29426556195402576, 0.5592739483213254
# 0.43568183787478515, 0.08735304466308257, 0.4769651174621324
# 0.8326627738907711, 0.08087231216891715, 0.08646491394031174
#
# Iteration time:0.112855, Total:6.460379
# nstate: 3, ndet: 3, nphot: 436084, niter: 50, loglik: -409408.0698347609 converged state: 0x3
# prior:
# 0.2662975864822551, 0.4193170472377801, 0.3143853662799648
# trans:
# 0.9999768637759662, 1.9414410283280024e-05, 3.7218137505763934e-06
# 7.5238564729416505e-06, 0.9999797024248471, 1.2773718679990002e-05
# 7.950151929591636e-06, 5.2062914162969096e-05, 0.9999399869339074
# obs:
# 0.1464098395450795, 0.2941203674699275, 0.559469792984993
# 0.4364692514725403, 0.08739332112823642, 0.4761374273992232
# 0.8342978721171499, 0.08057482329263269, 0.08512730459021732
#
# Iteration time:0.148279, Total:6.608658
# nstate: 3, ndet: 3, nphot: 436084, niter: 51, loglik: -409401.99727690814 converged state: 0x3
# prior:
# 0.26559464444724495, 0.42815912700873227, 0.3062462285440228
# trans:
# 0.9999768212668869, 1.9562251952347356e-05, 3.616481160672561e-06
# 7.596122700806916e-06, 0.999979909967718, 1.2493909581098363e-05
# 7.840131419376994e-06, 5.135476575483858e-05, 0.9999408051028259
# obs:
# 0.1463607483140851, 0.29399825452320155, 0.5596409971627133
# 0.4371492264766595, 0.08742756591484814, 0.4754232076084922
# 0.8356279881413998, 0.08031427910009273, 0.08405773275850734
#
# Iteration time:0.131301, Total:6.739959
# nstate: 3, ndet: 3, nphot: 436084, niter: 52, loglik: -409397.2205745028 converged state: 0x3
# prior:
# 0.2649618142269824, 0.43598628912982307, 0.29905189664319465
# trans:
# 0.9999767793453105, 1.969818718398345e-05, 3.5224675056068948e-06
# 7.66365972961145e-06, 0.9999800892076172, 1.224713265319778e-05
# 7.732079632085685e-06, 5.068960284089384e-05, 0.9999415783175271
# obs:
# 0.14631342394693442, 0.2938959506609983, 0.5597906253920673
# 0.4377369556024546, 0.0874566763492889, 0.47480636804825654
# 0.8367074429376762, 0.08008670145664636, 0.08320585560567755
#
# Iteration time:0.124197, Total:6.864156
# nstate: 3, ndet: 3, nphot: 436084, niter: 53, loglik: -409393.454496633 converged state: 0x3
# prior:
# 0.264394329777846, 0.4429019811027229, 0.292703689119431
# trans:
# 0.9999767383984414, 1.982299040602551e-05, 3.438611152574165e-06
# 7.72649214492826e-06, 0.9999802441659066, 1.2029341948603255e-05
# 7.627479418346042e-06, 5.007078586023646e-05, 0.9999423017347215
# obs:
# 0.146268045346494, 0.2938105421696049, 0.5599214124839011
# 0.438245506763594, 0.08748142790498793, 0.474273065331418
# 0.837581823329016, 0.0798882838379694, 0.08252989283301468
#
# Iteration time:0.129806, Total:6.993962
# nstate: 3, ndet: 3, nphot: 436084, niter: 54, loglik: -409390.47969678784 converged state: 0x3
# prior:
# 0.2638869828034876, 0.44900371549920065, 0.2871093016973117
# trans:
# 0.9999766987497595, 1.993740311051283e-05, 3.363847129985531e-06
# 7.784719224289825e-06, 0.9999803782559505, 1.1837024825241925e-05
# 7.527378818367657e-06, 4.949964672538639e-05, 0.9999429729744561
# obs:
# 0.14622476094440248, 0.29373946247483995, 0.5600357765807575
# 0.4386860874707767, 0.08750248335697093, 0.47381142917225233
# 0.8382890769576112, 0.07971549441388699, 0.08199542862850168
#
# Iteration time:0.115665, Total:7.109627
# nstate: 3, ndet: 3, nphot: 436084, niter: 55, loglik: -409388.1266120863 converged state: 0x3
# prior:
# 0.26343448706756295, 0.4543817198191889, 0.28218379311324815
# trans:
# 0.9999766606575536, 2.0042136446400533e-05, 3.2972059998973156e-06
# 7.83849511576799e-06, 0.99998049437877, 1.1667126114134473e-05
# 7.432469635408062e-06, 4.8976014957821636e-05, 0.9999435915154067
# obs:
# 0.14618368623355849, 0.2936804736682861, 0.5601358400981554
# 0.4390682884383567, 0.08752040553740245, 0.4734113060242409
# 0.838860579656952, 0.07956512391592163, 0.08157429642712642
#
# Iteration time:0.111051, Total:7.220678
# nstate: 3, ndet: 3, nphot: 436084, niter: 56, loglik: -409386.26345620095 converged state: 0x3
# prior:
# 0.26303169808613097, 0.4591183593595832, 0.27784994255428574
# trans:
# 0.9999766243173662, 2.013787245065732e-05, 3.2378101831439934e-06
# 7.888012780664584e-06, 0.9999805950046039, 1.1516982615413864e-05
# 7.343159153878839e-06, 4.8498642315005764e-05, 0.9999441581985311
# obs:
# 0.14614490200145722, 0.2936316425410022, 0.5602234554575405
# 0.4394003042239489, 0.08753567084439177, 0.47306402493165933
# 0.8393221257287131, 0.0794342988106776, 0.0812435754606093
#
# Iteration time:0.141729, Total:7.362407
# nstate: 3, ndet: 3, nphot: 436084, niter: 57, loglik: -409384.78728038794 converged state: 0x3
# prior:
# 0.26267373696459895, 0.463288071183733, 0.2740381918516681
# trans:
# 0.9999765898669878, 2.022526426939044e-05, 3.184868742849439e-06
# 7.93349110554719e-06, 0.999980682241607, 1.1384267287420827e-05
# 7.259632992148808e-06, 4.8065538505177334e-05, 0.9999446748285028
# obs:
# 0.14610845406947773, 0.2935913129847637, 0.5603002329457586
# 0.4396891302118738, 0.0875486820201014, 0.4727621877680247
# 0.8396948175293131, 0.07932047350710608, 0.08098470896358094
#
# Iteration time:0.113283, Total:7.47569
# nstate: 3, ndet: 3, nphot: 436084, niter: 58, loglik: -409383.6173011711 converged state: 0x3
# prior:
# 0.26235605314729477, 0.46695762084669196, 0.27068632600601333
# trans:
# 0.9999765573929082, 2.0304935761004122e-05, 3.1376713306963704e-06
# 7.97516466962995e-06, 0.9999807578932897, 1.1266942040660814e-05
# 7.181908501547208e-06, 4.767423180390637e-05, 0.9999451438596945
# obs:
# 0.14607435468666174, 0.2935580766277277, 0.5603675686856106
# 0.43994073630945213, 0.08755977954939312, 0.4724994841411547
# 0.8399958465931117, 0.07922141058787967, 0.08078274281900862
#
# Iteration time:0.13116, Total:7.60685
# nstate: 3, ndet: 3, nphot: 436084, niter: 59, loglik: -409382.68989100866 converged state: 0x3
# prior:
# 0.2620744496111468, 0.4701865501654992, 0.2677390002233539
# trans:
# 0.9999765269373985, 2.0377480822140548e-05, 3.0955817794291032e-06
# 8.013275723472582e-06, 0.9999808235063494, 1.1163217927076885e-05
# 7.109879001201524e-06, 4.732196783591759e-05, 0.9999455681531629
# obs:
# 0.1460425853382436, 0.2935307433099728, 0.5604266713517837
# 0.44016021848208864, 0.08756925149725445, 0.47227053002065694
# 0.8402391678804311, 0.07913515488325089, 0.0806256772363181
#
# Iteration time:0.132551, Total:7.739401
# nstate: 3, ndet: 3, nphot: 436084, niter: 60, loglik: -409381.95478790335 converged state: 0x3
# prior:
# 0.26182508576321456, 0.473027726224637, 0.26514718801214837
# trans:
# 0.9999764985056414, 2.0443462693390564e-05, 3.058031665226256e-06
# 8.048067996572565e-06, 0.9999808804104408, 1.107152156278518e-05
# 7.043349633082845e-06, 4.700585841081364e-05, 0.9999459507919561
# obs:
# 0.14601310055662786, 0.2935083126298736, 0.5604785868134985
# 0.44035192976049053, 0.0875773418401351, 0.47207072839937425
# 0.8404360740046067, 0.07906000510480848, 0.08050392089058472
#
# Iteration time:0.121571, Total:7.860972
# nstate: 3, ndet: 3, nphot: 436084, niter: 61, loglik: -409381.37220202235 converged state: 0x3
# prior:
# 0.26160446758653927, 0.47552793193807785, 0.26286760047538277
# trans:
# 0.9999764720725336, 2.050341341698183e-05, 3.0245140494510345e-06
# 8.079782006140797e-06, 0.9999809297512482, 1.0990466745648878e-05
# 6.982065856777575e-06, 4.6722990637287714e-05, 0.9999462949435058
# obs:
# 0.1459858322939969, 0.29348994740623163, 0.5605242202997714
# 0.44051959264878804, 0.0875842574501238, 0.4718961499010881
# 0.8405956789709441, 0.07899448536096661, 0.0804098356680892
#
# Iteration time:0.117624, Total:7.978596
# nstate: 3, ndet: 3, nphot: 436084, niter: 62, loglik: -409380.9105873032 converged state: 0x3
# prior:
# 0.26140943082498724, 0.4777284596908568, 0.260862109484156
# trans:
# 0.9999764475889243, 2.055783354676436e-05, 2.9945775289253766e-06
# 8.108651588018168e-06, 0.9999809725180353, 1.0918830376719262e-05
# 6.92573567077383e-06, 4.647050487124e-05, 0.9999466037594579
# obs:
# 0.14596069446787682, 0.2934749495594191, 0.5605643559727039
# 0.4406663949854781, 0.0875901739227542, 0.47174343109176764
# 0.8407253220132394, 0.0789373179447867, 0.08033736004197388
#
# Iteration time:0.115873, Total:8.094469
# nstate: 3, ndet: 3, nphot: 436084, niter: 63, loglik: -409380.5449110105 converged state: 0x3
# prior:
# 0.26123712063585164, 0.47966568423614314, 0.2590971951280051
# trans:
# 0.999976424987176, 2.0607192155825436e-05, 2.9678206681303522e-06
# 8.134901413807862e-06, 0.9999810095666457, 1.0855531940471762e-05
# 6.874046612183388e-06, 4.6245648517181094e-05, 0.9999468803048707
# obs:
# 0.14593758737783746, 0.29346273864131744, 0.5605996739808451
# 0.44079507130199386, 0.08759524043520064, 0.47160968826280547
# 0.8408309021619934, 0.07888739816416623, 0.0802816996738404
#
# Iteration time:0.114036, Total:8.208505
# nstate: 3, ndet: 3, nphot: 436084, niter: 64, loglik: -409380.2553003064 converged state: 0x3
# prior:
# 0.2610849697073816, 0.48137160098725157, 0.25754342930536683
# trans:
# 0.9999764041860031, 2.0651927148231777e-05, 2.9438868487335877e-06
# 8.15874529623785e-06, 0.9999810416387731, 1.079961593071038e-05
# 6.826678495353081e-06, 4.604581135564248e-05, 0.9999471275101491
# obs:
# 0.14591640178421725, 0.29345283304198333, 0.5606307651737994
# 0.44090797162606105, 0.08759958380184264, 0.4714924445720962
# 0.8409171536305636, 0.07884377157555295, 0.08023907479388352
#
# Iteration time:0.118408, Total:8.326913
# nstate: 3, ndet: 3, nphot: 436084, niter: 65, loglik: -409380.0259774385 converged state: 0x3
# prior:
# 0.2609506759981647, 0.4828743225065674, 0.25617500149526784
# trans:
# 0.9999763850945975, 2.0692445856018332e-05, 2.922459546455017e-06
# 8.180385117850304e-06, 0.9999810693781596, 1.0750236722557889e-05
# 6.783312732173758e-06, 4.586854692474178e-05, 0.999947348140343
# obs:
# 0.14589702252285222, 0.2934448337636206, 0.5606581437135271
# 0.4410071195229508, 0.087603311869366, 0.4713895686076832
# 0.8409878712311589, 0.07880561371937128, 0.08020651504946981
#
# Iteration time:0.129732, Total:8.456645
# nstate: 3, ndet: 3, nphot: 436084, niter: 66, loglik: -409379.84441819036 converged state: 0x3
# prior:
# 0.26083218077428644, 0.4841985303623584, 0.2549692888633551
# trans:
# 0.9999763676160839, 2.0729125887502565e-05, 2.9032580287513237e-06
# 8.200010246722871e-06, 0.9999810933442678, 1.0706645485563912e-05
# 6.743638952428732e-06, 4.571158353193143e-05, 0.9999475447775156
# obs:
# 0.14587933159664265, 0.2934384105677386, 0.5606822578356186
# 0.4410942609843689, 0.0876065163690442, 0.4712992226465868
# 0.8410460940097666, 0.07877221229297579, 0.08018169369725774
#
# Iteration time:0.112008, Total:8.568653
# nstate: 3, ndet: 3, nphot: 436084, niter: 67, loglik: -409379.7006846126 converged state: 0x3
# prior:
# 0.2607276473480976, 0.4853658823165823, 0.25390647033531993
# trans:
# 0.9999763516503579, 2.0762316185522384e-05, 2.886033456444348e-06
# 8.217797327410446e-06, 0.9999811140238622, 1.0668178810219939e-05
# 6.707359522764656e-06, 4.557282769243162e-05, 0.9999477198127849
# obs:
# 0.1458632107342597, 0.2934332902567607, 0.5607034990089796
# 0.4411709055817977, 0.08760927532197295, 0.47121981909622934
# 0.8410942542326065, 0.0787429516033025, 0.08016279416409093
#
# Iteration time:0.118521, Total:8.687174
# nstate: 3, ndet: 3, nphot: 436084, niter: 68, loglik: -409379.5868947471 converged state: 0x3
# prior:
# 0.26063544076710476, 0.48639537652501247, 0.2529691827078827
# trans:
# 0.9999763370963818, 2.0792338251875823e-05, 2.870565366276769e-06
# 8.233910356092954e-06, 0.9999811318408617, 1.0634248782308981e-05
# 6.6741924540575435e-06, 4.545036216071447e-05, 0.9999478754453852
# obs:
# 0.14584854343994996, 0.29342924683540156, 0.5607222097246485
# 0.44123836111210035, 0.08761165507456357, 0.47114998381333606
# 0.8411342978376969, 0.07871729909377513, 0.08014840306852788
#
# Iteration time:0.136961, Total:8.824135
# nstate: 3, ndet: 3, nphot: 436084, niter: 69, loglik: -409379.4968006888 converged state: 0x3
# prior:
# 0.2605541086087717, 0.48730367542494274, 0.2521422159662854
# trans:
# 0.9999763238539966, 2.081948749539232e-05, 2.856658508138237e-06
# 8.24850096640037e-06, 0.9999811471647445, 1.0604334289097426e-05
# 6.643873091788867e-06, 4.534244021712991e-05, 0.9999480136866912
# obs:
# 0.14583521657915657, 0.2934260933004347, 0.5607386901204088
# 0.4412977627865601, 0.08761371202655324, 0.47108852518688654
# 0.8411677815244577, 0.07869479372238632, 0.08013742475315588
#
# Iteration time:0.112613, Total:8.936748
# nstate: 3, ndet: 3, nphot: 436084, niter: 70, loglik: -409379.42545262736 converged state: 0x3
# prior:
# 0.26048236297726557, 0.4881053924971142, 0.2514122445256203
# trans:
# 0.9999763118253264, 2.084403466425121e-05, 2.8441400093587923e-06
# 8.261708867004835e-06, 0.9999811603177522, 1.057797338064585e-05
# 6.616154903155846e-06, 4.5247477472034304e-05, 0.9999481363676248
# obs:
# 0.1458231215554783, 0.2934236748226182, 0.5607532036219034
# 0.44135009785463614, 0.08761549410176242, 0.47103440804360147
# 0.8411959508122803, 0.07867503596894712, 0.08012901321877246
#
# Iteration time:0.110129, Total:9.046877
# nstate: 3, ndet: 3, nphot: 436084, niter: 71, loglik: -409379.36893135495 converged state: 0x3
# prior:
# 0.2604190637554526, 0.4888133452833549, 0.2507675909611923
# trans:
# 0.999976300915834, 2.086622732755581e-05, 2.8328568384222526e-06
# 8.273662384165555e-06, 0.9999811715810751, 1.055475654066013e-05
# 6.590809607287802e-06, 4.5164042135295554e-05, 0.9999482451482574
# obs:
# 0.14581215513825777, 0.29342186310637147, 0.5607659817553708
# 0.44139622641271253, 0.0876170420023416, 0.47098673158494586
# 0.8412198026623647, 0.07865767926154407, 0.08012251807609119
#
# Iteration time:0.148553, Total:9.19543
# nstate: 3, ndet: 3, nphot: 436084, niter: 72, loglik: -409379.3241353012 converged state: 0x3
# prior:
# 0.2603632031326062, 0.4894387780336066, 0.25019801883378734
# trans:
# 0.9999762910350827, 2.0886291376018382e-05, 2.82267354119708e-06
# 8.284479072386274e-06, 0.9999811812001816, 1.0534320745918787e-05
# 6.567626839833554e-06, 4.5090844453592946e-05, 0.9999483415287065
# obs:
# 0.14580221999901552, 0.2934205517373075, 0.560777228263677
# 0.4414368990257312, 0.08761839027980725, 0.4709447106944616
# 0.8412401356239428, 0.07864242263009638, 0.08011744174596085
#
# Iteration time:0.114142, Total:9.309572
# nstate: 3, ndet: 3, nphot: 436084, niter: 73, loglik: -409379.2886111665 converged state: 0x3
# prior:
# 0.26031389140155725, 0.4899915572231126, 0.2496945513753301
# trans:
# 0.9999762820972594, 2.0904432516536013e-05, 2.813470224038471e-06
# 8.294266364491257e-06, 0.9999811893894225, 1.0516344212919307e-05
# 6.546413498704378e-06, 4.502672582777585e-05, 0.9999484268606735
# obs:
# 0.14579322501098813, 0.2934196523527571, 0.5607871226362549
# 0.4414727716851506, 0.08761956825032051, 0.47090766006452883
# 0.8412575899293364, 0.07862900441517706, 0.08011340565548655
#
# Iteration time:0.11105, Total:9.420622
# nstate: 3, ndet: 3, nphot: 436084, niter: 74, loglik: -409379.2604192054 converged state: 0x3
# prior:
# 0.26027034399733273, 0.49048034297502763, 0.24924931302763964
# trans:
# 0.9999762740215001, 2.0920837740158314e-05, 2.805140759671737e-06
# 8.303122239042065e-06, 0.999981196336015, 1.0500541746070744e-05
# 6.5269928822743215e-06, 4.497064797623707e-05, 0.9999485023591415
# obs:
# 0.14578508536036333, 0.2934190914941057, 0.560795823145531
# 0.44150441853825007, 0.0876206007770589, 0.4708749806846909
# 0.8412726795125496, 0.07861719688084684, 0.08011012360660348
#
# Iteration time:0.131622, Total:9.552244
# nstate: 3, ndet: 3, nphot: 436084, niter: 75, loglik: -409379.2380262785 converged state: 0x3
# prior:
# 0.2602318697320654, 0.490912739180824, 0.24885539108711058
# trans:
# 0.9999762667320593, 2.0935676747259623e-05, 2.797591193457206e-06
# 8.311135888372294e-06, 0.9999812022034972, 1.0486660614378028e-05
# 6.509203703351441e-06, 4.49216823987346e-05, 0.9999485691138978
# obs:
# 0.14577772251154666, 0.29341880802161774, 0.5608034694668356
# 0.4415323427497748, 0.08762150893886375, 0.4708461483113613
# 0.8412858175526515, 0.0786068015999307, 0.08010738084741781
#
# Iteration time:0.109895, Total:9.662139
# nstate: 3, ndet: 3, nphot: 436084, niter: 76, loglik: -409379.2202209377 converged state: 0x3
# prior:
# 0.26019786016773316, 0.49129542485395306, 0.24850671497831392
# trans:
# 0.999976260158353, 2.09491033176104e-05, 2.790738329394626e-06
# 8.31838837480299e-06, 0.9999812071347313, 1.0474476893852531e-05
# 6.492899040340062e-06, 4.487900031067191e-05, 0.999948628100649
# obs:
# 0.145771064062402, 0.2934187509917018, 0.5608101849458962
# 0.4415569857952099, 0.08762231060139662, 0.4708207036033936
# 0.8412973368355416, 0.07859764549824036, 0.08010501766621787
#
# Iteration time:0.124302, Total:9.786441
# nstate: 3, ndet: 3, nphot: 436084, niter: 77, loglik: -409379.20604611485 converged state: 0x3
# prior:
# 0.2601677800589304, 0.4916342689961515, 0.24819795094491806
# trans:
# 0.9999762542349067, 2.0961256616390346e-05, 2.784508476956144e-06
# 8.324953266025638e-06, 0.9999812112545124, 1.0463792221351804e-05
# 6.477945270064479e-06, 4.484186315467931e-05, 0.9999486801915752
# obs:
# 0.14576504351940484, 0.2934188779134399, 0.5608160785671552
# 0.4415787354338208, 0.08762302090463644, 0.47079824366154277
# 0.8413075059758094, 0.0785895774604495, 0.0801029165637411
#
# Iteration time:0.151429, Total:9.93787
# nstate: 3, ndet: 3, nphot: 436084, niter: 78, loglik: -409379.1947457744 converged state: 0x3
# prior:
# 0.2601411587918701, 0.49193443101008916, 0.2479244101980408
# trans:
# 0.9999762489012284, 2.09722624300689e-05, 2.7788363415261764e-06
# 8.330897243348343e-06, 0.9999812146718441, 1.0454430912545812e-05
# 6.4642210137160975e-06, 4.480961374960841e-05, 0.9999487261652367
# obs:
# 0.14575960001716282, 0.29341915331562246, 0.5608212466672148
# 0.4415979325673884, 0.08762365267855828, 0.47077841475405324
# 0.8413165423352775, 0.07858246541458654, 0.0801009922501359
#
# Iteration time:0.120855, Total:10.058725
# nstate: 3, ndet: 3, nphot: 436084, niter: 79, loglik: -409379.18572271406 converged state: 0x3
# prior:
# 0.2601175827427526, 0.49220044846201755, 0.24768196879522966
# trans:
# 0.9999762441016287, 2.098223432847299e-05, 2.7736640428272226e-06
# 8.336280678627265e-06, 0.9999812174819187, 1.0446237402646225e-05
# 6.451616117486297e-06, 4.4781668102938916e-05, 0.9999487667157796
# obs:
# 0.14575467800194225, 0.29341954756770366, 0.5608257744303541
# 0.4416148771557078, 0.0876242167971751, 0.47076090604711707
# 0.841324622308606, 0.07857619382448779, 0.08009918386690613
#
# Iteration time:0.127023, Total:10.185748
# nstate: 3, ndet: 3, nphot: 436084, niter: 80, loglik: -409379.1785051299 converged state: 0x3
# prior:
# 0.2600966884780228, 0.4924363137866556, 0.24746699773532155
# trans:
# 0.9999762397850015, 2.099127475134126e-05, 2.7689402472225057e-06
# 8.341158177363818e-06, 0.999981219767849, 1.0439073973517095e-05
# 6.4400306820083605e-06, 4.475750788823043e-05, 0.9999488024614297
# obs:
# 0.14575022689469955, 0.293420035908311, 0.5608297371969895
# 0.44162983333129874, 0.08762472247971746, 0.4707454441889837
# 0.8413318895120576, 0.07857066153020664, 0.08009744895773571
#
# Iteration time:0.15982, Total:10.345568
# nstate: 3, ndet: 3, nphot: 436084, niter: 81, loglik: -409379.1727202423 converged state: 0x3
# prior:
# ...
# prior:
# 0.2599163554385359, 0.49437567936286736, 0.24570796519859675
# trans:
# 0.9999762010260743, 2.1091306330144846e-05, 2.7076675956654056e-06
# 8.392743965835218e-06, 0.9999812082863144, 1.0398969719688535e-05
# 6.290749096883897e-06, 4.4661421097015064e-05, 0.9999490478298061
# obs:
# 0.14570432945250422, 0.29344302595723293, 0.5608526445902628
# 0.441739563891489, 0.08763103417021549, 0.47062940193829544
# 0.8414283932255007, 0.07852868427110442, 0.08004292250339505
#
# Iteration time:0.130814, Total:22.438756
# nstate: 3, ndet: 3, nphot: 436084, niter: 173, loglik: -409379.1470202167 converged state: 0x3
# prior:
# 0.259916338003908, 0.4943757622756148, 0.24570789972047727
# trans:
# 0.9999762010239454, 2.1091324898314055e-05, 2.7076511562498677e-06
# 8.39275120947514e-06, 0.9999812082693017, 1.0398979488723888e-05
# 6.290716116822631e-06, 4.4661473528315996e-05, 0.9999490478103549
# obs:
# 0.1457043230883133, 0.293443037036688, 0.5608526398749987
# 0.4417395605090375, 0.0876310359775074, 0.4706294035134551
# 0.8414284210968619, 0.07852868423636435, 0.08004289466677379
#
# Iteration time:0.161118, Total:22.599874
# nstate: 3, ndet: 3, nphot: 436084, niter: 174, loglik: -409379.147020187 converged state: 0x3
# prior:
# 0.2599163215119866, 0.494375840547774, 0.24570783794023934
# trans:
# 0.9999762010219351, 2.109134246557591e-05, 2.707635599434418e-06
# 8.39275805839724e-06, 0.9999812082532012, 1.0398988740410104e-05
# 6.290684924211902e-06, 4.466152315668818e-05, 0.9999490477919191
# obs:
# 0.1457043170695407, 0.29344304752037736, 0.5608526354100819
# 0.4417395572963279, 0.08763103768758065, 0.4706294050160915
# 0.8414284474664869, 0.07852868420762942, 0.08004286832588375
#
# Iteration time:0.120778, Total:22.720652
# nstate: 3, ndet: 3, nphot: 436084, niter: 175, loglik: -409379.1470201584 converged state: 0x3
# prior:
# 0.25991630591139, 0.49437591444899176, 0.2457077796396183
# trans:
# 0.999976201020036, 2.109135908603002e-05, 2.70762087790628e-06
# 8.392764534355644e-06, 0.999981208237964, 1.0398997501661123e-05
# 6.2906554216113e-06, 4.466157013067275e-05, 0.9999490477744477
# obs:
# 0.14570431137727488, 0.2934430574402884, 0.5608526311824366
# 0.44173955424561445, 0.08763103930566214, 0.4706294064487235
# 0.8414284724153515, 0.07852868418410903, 0.08004284340053955
#
# Iteration time:0.113104, Total:22.833756
# nstate: 3, ndet: 3, nphot: 436084, niter: 176, loglik: -409379.14702013193 converged state: 0x3
# prior:
# 0.25991629115359594, 0.4943759842321702, 0.24570772461423399
# trans:
# 0.9999762010182423, 2.109137481082976e-05, 2.707606946883034e-06
# 8.392770657879941e-06, 0.9999812082235441, 1.0399005798043547e-05
# 6.290627516949804e-06, 4.466161459109618e-05, 0.999949047757892
# obs:
# 0.14570430599365547, 0.29344306682669746, 0.560852627179647
# 0.4417395513494119, 0.08763104083669776, 0.47062940781389034
# 0.8414284960200595, 0.07852868416510755, 0.08004281981483309
#
# Iteration time:0.140115, Total:22.973871
# nstate: 3, ndet: 3, nphot: 436084, niter: 177, loglik: -409379.14702011104 converged state: 0x3
# prior:
# 0.2599162771927649, 0.49437605013462094, 0.24570767267261412
# trans:
# 0.9999762010165477, 2.1091389688349194e-05, 2.7075937639794793e-06
# 8.392776448345974e-06, 0.9999812082098977, 1.0399013653840436e-05
# 6.290601123223132e-06, 4.466165667144673e-05, 0.9999490477422053
# obs:
# 0.14570430090181768, 0.2934430757082611, 0.5608526233899211
# 0.4417395486004993, 0.08763104228536807, 0.4706294091141328
# 0.8414285183530781, 0.07852868415001431, 0.08004279749690768
#
# Iteration time:0.124922, Total:23.098793
# nstate: 3, ndet: 3, nphot: 436084, niter: 178, loglik: -409379.1470200902 converged state: 0x3
# prior:
# 0.25991626398559553, 0.4943761123791267, 0.24570762363527776
# trans:
# 0.9999762010149466, 2.1091403764334174e-05, 2.707581289078585e-06
# 8.392781924044028e-06, 0.9999812081969838, 1.0399021092108593e-05
# 6.290576158210602e-06, 4.466169649824566e-05, 0.9999490477273436
# obs:
# 0.14570429608583138, 0.2934430841120976, 0.560852619802071
# 0.441739545991918, 0.0876310436561012, 0.4706294103519808
# 0.841428539482964, 0.07852868413829252, 0.08004277637874337
#
# Iteration time:0.128408, Total:23.227201
# nstate: 3, ndet: 3, nphot: 436084, niter: 179, loglik: -409379.1470200725 converged state: 0x3
# prior:
# 0.25991625149117226, 0.4943761711749209, 0.24570757733390683
# trans:
# 0.9999762010134338, 2.1091417082047805e-05, 2.7075694842102124e-06
# 8.39278710224104e-06, 0.9999812081847629, 1.0399028134737636e-05
# 6.290552544206785e-06, 4.4661734191391695e-05, 0.9999490477132644
# obs:
# 0.14570429153065065, 0.29344309206387614, 0.5608526164054732
# 0.4417395435169766, 0.08763104495308813, 0.47062941152993537
# 0.8414285594745725, 0.0785286841294717, 0.08004275639595575
#
# Iteration time:0.149258, Total:23.376459
# nstate: 3, ndet: 3, nphot: 436084, niter: 180, loglik: -409379.1470200598 converged state: 0x3
# prior:
# 0.2599162396708337, 0.49437622671859394, 0.2457075336105724
# trans:
# 0.9999762010120042, 2.1091429682406858e-05, 2.7075583134369686e-06
# 8.392791999240562e-06, 0.9999812081731982, 1.0399034802501946e-05
# 6.29053020777016e-06, 4.466176986450159e-05, 0.9999490476999277
# obs:
# 0.1457042872220617, 0.29344309958788856, 0.5608526131900498
# 0.4417395411692444, 0.08763104618029474, 0.4706294126504609
# 0.8414285783892587, 0.07852868412313908, 0.0800427374876023
#
# Iteration time:0.128298, Total:23.504757
# nstate: 3, ndet: 3, nphot: 436084, niter: 181, loglik: -409379.14702004177 converged state: 0x3
# prior:
# 0.2599162284880409, 0.4943762791949247, 0.24570749231703432
# trans:
# 0.9999762010106531, 2.109144160411059e-05, 2.707547742745211e-06
# 8.392796630437391e-06, 0.9999812081622543, 1.039904111511609e-05
# 6.2905090794846305e-06, 4.4661803625222166e-05, 0.9999490476872953
# obs:
# 0.14570428314663425, 0.2934431067071233, 0.5608526101462424
# 0.44173953894255336, 0.08763104734147316, 0.47062941371597355
# 0.8414285962850667, 0.07852868411893345, 0.08004271959599972
#
# Iteration time:0.121259, Total:23.626016
# nstate: 3, ndet: 3, nphot: 436084, niter: 182, loglik: -409379.1470200281 converged state: 0x3
# prior:
# 0.25991621790826075, 0.49437632877765997, 0.2457074533140792
# trans:
# 0.9999762010093763, 2.1091452883761666e-05, 2.7075377399419863e-06
# 8.392801010370766e-06, 0.9999812081518984, 1.0399047091283137e-05
# 6.290489093736053e-06, 4.466183557553677e-05, 0.9999490476753307
# obs:
# 0.1457042792916799, 0.2934431134433388, 0.5608526072649813
# 0.4417395368309884, 0.08763104844017487, 0.4706294147288369
# 0.8414286132169091, 0.07852868411653889, 0.08004270266655202
#
# Iteration time:0.139604, Total:23.76562
# nstate: 3, ndet: 3, nphot: 436084, niter: 183, loglik: -409379.1470200182 converged state: 0x3
# prior:
# 0.2599162078988478, 0.4943763756302252, 0.2457074164709269
# trans:
# 0.9999762010081694, 2.109146355598223e-05, 2.707528274558923e-06
# 8.392805152772454e-06, 0.9999812081420986, 1.0399052748746844e-05
# 6.290470188500411e-06, 4.4661865812053635e-05, 0.9999490476639994
# obs:
# 0.14570427564520785, 0.2934431198171223, 0.5608526045376698
# 0.44173953482888545, 0.08763104947975978, 0.47062941569135475
# 0.8414286292367368, 0.07852868411567883, 0.08004268664758442
#
# Iteration time:0.124217, Total:23.889837
# nstate: 3, ndet: 3, nphot: 436084, niter: 184, loglik: -409379.147020008 converged state: 0x3
# prior:
# 0.25991619842894575, 0.4943764199063928, 0.24570738166466138
# trans:
# 0.9999762010070287, 2.109147365352007e-05, 2.707519317758541e-06
# 8.392809070613498e-06, 0.999981208132825, 1.0399058104334219e-05
# 6.290452305145473e-06, 4.466189442628356e-05, 0.9999490476532685
# obs:
# 0.14570427219588758, 0.29344312584796167, 0.5608526019561507
# 0.4417395329308259, 0.08763105046340736, 0.4706294166057668
# 0.8414286443936964, 0.07852868411611247, 0.08004267149019123
#
# Iteration time:0.116279, Total:24.006116
# nstate: 3, ndet: 3, nphot: 436084, niter: 185, loglik: -409379.14701999945 converged state: 0x3
# prior:
# 0.2599161894693796, 0.49437646175089506, 0.24570734877972544
# trans:
# 0.9999762010059504, 2.1091483207352744e-05, 2.707510842248329e-06
# 8.392812776147013e-06, 0.9999812081240499, 1.0399063174002864e-05
# 6.290435388242099e-06, 4.466192150489966e-05, 0.9999490476431069
# obs:
# 0.14570426893300967, 0.29344313155429397, 0.5608525995126963
# 0.4417395311316289, 0.08763105139412625, 0.47062941747424497
# 0.8414286587342853, 0.07852868411762928, 0.08004265714808541
#
# Iteration time:0.138906, Total:24.145022
# nstate: 3, ndet: 3, nphot: 436084, niter: 186, loglik: -409379.1470199946 converged state: 0x3
# prior:
# 0.25991618099256575, 0.4943765012999969, 0.2457073177074373
# trans:
# 0.9999762010049309, 2.1091492246783267e-05, 2.707502822197852e-06
# 8.392816280949047e-06, 0.9999812081157462, 1.039906797288499e-05
# 6.29041938538705e-06, 4.46619471299865e-05, 0.9999490476334846
# obs:
# 0.14570426584645269, 0.2934431369535695, 0.5608525971999778
# 0.4417395294263466, 0.08763105227476362, 0.4706294182988898
# 0.8414286723024934, 0.07852868412004584, 0.08004264357746073
#
# Iteration time:0.120526, Total:24.265548
# nstate: 3, ndet: 3, nphot: 436084, niter: 187, loglik: -409379.1470199817 converged state: 0x3
# prior:
# 0.2599161729724265, 0.4943765386820305, 0.24570728834554298
# trans:
# 0.9999762010039673, 2.1091500799530624e-05, 2.7074952331598837e-06
# 8.392819595957078e-06, 0.9999812081078888, 1.0399072515324896e-05
# 6.290404247036861e-06, 4.4661971379283736e-05, 0.9999490476243736
# obs:
# 0.14570426292664918, 0.29344314206229893, 0.5608525950110519
# 0.44173952781025105, 0.08763105310801322, 0.4706294190817358
# 0.8414286851399372, 0.07852868412320348, 0.08004263073685931
#
# Iteration time:0.11136, Total:24.376908
# nstate: 3, ndet: 3, nphot: 436084, niter: 188, loglik: -409379.1470199772 converged state: 0x3
# prior:
# 0.25991616538429757, 0.4943765740178854, 0.245707260597817
# trans:
# 0.9999762010030561, 2.1091508891817722e-05, 2.707488051997958e-06
# 8.392822731505724e-06, 0.9999812081004535, 1.0399076814921259e-05
# 6.290389926348537e-06, 4.466199432640343e-05, 0.9999490476157473
# obs:
# 0.1457042601645564, 0.29344314689611006, 0.5608525929393335
# 0.4417395262788378, 0.08763105389642385, 0.4706294198247385
# 0.8414286972859898, 0.07852868412696394, 0.08004261858704623
#
# Iteration time:0.137675, Total:24.514583
# nstate: 3, ndet: 3, nphot: 436084, niter: 189, loglik: -409379.14701997396 converged state: 0x3
# prior:
# 0.2599161582048604, 0.4943766074214705, 0.24570723437366895
# trans:
# 0.9999762010021949, 2.1091516548450272e-05, 2.7074812568145e-06
# 8.392825697361231e-06, 0.9999812080934182, 1.0399080884562213e-05
# 6.2903763790318805e-06, 4.4662016041050744e-05, 0.99994904760758
# obs:
# 0.14570425755162436, 0.2934431514697891, 0.5608525909785865
# 0.44173952482780754, 0.08763105464240815, 0.4706294205297843
# 0.8414287087779004, 0.07852868413120818, 0.08004260709089145
#
# Iteration time:0.114055, Total:24.628638
# nstate: 3, ndet: 3, nphot: 436084, niter: 190, loglik: -409379.1470199662 converged state: 0x3
# prior:
# 0.2599161514120577, 0.49437663900014545, 0.24570720958779677
# trans:
# 0.9999762010013803, 2.1091523792896865e-05, 2.707474826886679e-06
# 8.392828502752354e-06, 0.9999812080867608, 1.0399084736463887e-05
# 6.29036356320821e-06, 4.4662036589225404e-05, 0.9999490475998476
# obs:
# 0.1457042550797716, 0.29344315579732744, 0.5608525891229009
# 0.4417395234530632, 0.08763105534824785, 0.47062942119868906
# 0.8414287196509117, 0.07852868413583221, 0.08004259621325609
#
# Iteration time:0.12123, Total:24.749868
# nstate: 3, ndet: 3, nphot: 436084, niter: 191, loglik: -409379.1470199627 converged state: 0x3
# prior:
# 0.25991614498503446, 0.4943766688551147, 0.24570718615985088
# trans:
# 0.99997620100061, 2.1091530647357542e-05, 2.7074687426012306e-06
# 8.39283115640177e-06, 0.9999812080804615, 1.0399088382200875e-05
# 6.290351439278679e-06, 4.466205603341831e-05, 0.9999490475925273
# obs:
# 0.14570425274135543, 0.29344315989196507, 0.5608525873666794
# 0.44173952215070433, 0.08763105601610284, 0.4706294218331928
# 0.8414287299383647, 0.0785286841407475, 0.08004258592088784
#
# Iteration time:0.145979, Total:24.895847
# nstate: 3, ndet: 3, nphot: 436084, niter: 192, loglik: -409379.1470199594 converged state: 0x3
# prior:
# 0.25991613890405985, 0.49437669708180493, 0.24570716401413514
# trans:
# 0.9999762009998817, 2.1091537132836153e-05, 2.7074629853969563e-06
# 8.392833666553098e-06, 0.9999812080745007, 1.0399091832742114e-05
# 6.2903399697976655e-06, 4.4662074432789326e-05, 0.9999490475855974
# obs:
# 0.14570425052915223, 0.293443163766232, 0.5608525857046158
# 0.44173952091701624, 0.08763105664801671, 0.47062942243496714
# 0.8414287396718044, 0.0785286841458773, 0.08004257618231816
#
# Iteration time:0.136985, Total:25.032832
# nstate: 3, ndet: 3, nphot: 436084, niter: 193, loglik: -409379.14701995696 converged state: 0x3
# prior:
# 0.2599161331504782, 0.49437672377021175, 0.24570714307931008
# trans:
# 0.999976200999193, 2.109154326920303e-05, 2.7074575377077514e-06
# 8.392836040998936e-06, 0.9999812080688605, 1.0399095098478905e-05
# 6.290329119355891e-06, 4.466209184334902e-05, 0.9999490475790372
# obs:
# 0.14570424843633017, 0.2934431674319828, 0.560852584131687
# 0.4417395197484623, 0.08763105724592328, 0.47062942300561444
# 0.8414287488810753, 0.07852868415115656, 0.08004256696776811
#
# Iteration time:0.123488, Total:25.15632
# nstate: 3, ndet: 3, nphot: 436084, niter: 194, loglik: -409379.1470199531 converged state: 0x3
# prior:
# 0.25991612770663786, 0.494376749005226, 0.24570712328813626
# trans:
# 0.9999762009985418, 2.109154907525791e-05, 2.7074523829096395e-06
# 8.392838287104687e-06, 0.9999812080635236, 1.0399098189256766e-05
# 6.290318854467944e-06, 4.466210831811955e-05, 0.9999490475728273
# obs:
# 0.14570424645642996, 0.29344317090043653, 0.5608525826431335
# 0.4417395186416817, 0.08763105781165186, 0.4706294235466664
# 0.8414287575944126, 0.07852868415652904, 0.08004255824905848
#
# Iteration time:0.157137, Total:25.313457
# nstate: 3, ndet: 3, nphot: 436084, niter: 195, loglik: -409379.1470199474 converged state: 0x3
# prior:
# 0.2599161225558474, 0.49437677286693577, 0.24570710457721687
# trans:
# 0.9999762009979261, 2.1091554568786216e-05, 2.70744750527001e-06
# 8.392840411833331e-06, 0.9999812080584739, 1.039910111440273e-05
# 6.290309143467381e-06, 4.466212390729478e-05, 0.9999490475669492
# obs:
# 0.1457042445833448, 0.29344317418220744, 0.5608525812344477
# 0.4417395175934743, 0.0876310583469341, 0.47062942405959163
# 0.8414287658385297, 0.07852868416194764, 0.08004254999952262
#
# Iteration time:0.137359, Total:25.450816
# nstate: 3, ndet: 3, nphot: 436084, niter: 196, loglik: -409379.1470199453 converged state: 0x3
# prior:
# 0.25991611768231615, 0.4943767954309139, 0.24570708688676998
# trans:
# 0.9999762009973434, 2.1091559766615264e-05, 2.707442889900281e-06
# 8.392842421766934e-06, 0.9999812080536956, 1.0399103882751398e-05
# 6.290299956407019e-06, 4.4662138658388774e-05, 0.9999490475613851
# obs:
# 0.14570424281129798, 0.29344317728734143, 0.5608525799013605
# 0.4417395166008013, 0.087631058853408, 0.47062942454579065
# 0.8414287736387007, 0.078528684167372, 0.08004254219392723
#
# Iteration time:0.120288, Total:25.571104
# nstate: 3, ndet: 3, nphot: 436084, niter: 197, loglik: -409379.1470199435 converged state: 0x3
# prior:
# 0.2599161130711074, 0.4943768167684792, 0.24570707016041338
# trans:
# 0.9999762009967926, 2.1091564684664417e-05, 2.7074385227098084e-06
# 8.392844323128725e-06, 0.9999812080491743, 1.0399106502669929e-05
# 6.290291264964937e-06, 4.466215261637819e-05, 0.9999490475561186
# obs:
# 0.1457042411348278, 0.2934431802253421, 0.5608525786398301
# 0.44173951566077213, 0.08763105933262351, 0.4706294250066043
# 0.8414287810188389, 0.07852868417276818, 0.08004253480839289
#
# Iteration time:0.146723, Total:25.717827
# nstate: 3, ndet: 3, nphot: 436084, niter: 198, loglik: -409379.1470199393 converged state: 0x3
# prior:
# 0.25991610870808807, 0.49437683694695156, 0.24570705434496037
# trans:
# 0.9999762009962716, 2.109156933799684e-05, 2.707434390364952e-06
# 8.392846121801892e-06, 0.9999812080448961, 1.039910898208397e-05
# 6.290283042355348e-06, 4.466216582383388e-05, 0.9999490475511338
# obs:
# 0.1457042395487687, 0.29344318300520317, 0.5608525774460281
# 0.4417395147706428, 0.08763105978604728, 0.47062942544330977
# 0.8414287880015666, 0.07852868417810852, 0.08004252782032475
#
# Iteration time:0.136693, Total:25.85452
# The model converged after 198 iterations

# %% [markdown]
# What is the advantage of `IPyPrinter`?
#
# Because it uses a DisplayHandle, it can fully clear the output each iteration, while `StdPrinter`
#
# relies on `\r` characters to overwrite the previous output, which can only overwrite the last line.
#
# So if you plan to use `print_func='all'`, then `IPyPrinter` is recomended.
#
# On the other hand, using `DisplayHandle` means that the `IPyPrinter` is slightly slower.

# %% [markdown]
# ### Custom Printers
#
# `H2MM_C` does not strictly enforce any typing on `print_formatter` objects,
# operating on the principle of [Duck Typing](https://en.wikipedia.org/wiki/Duck_typing)
#
# All that is required is that calling
# `print_formatter(print_stream, *print_args, **print_kwargs)` will create an object
# that has `.update` and `.close` methods that take 1 and 0 arguments respectively,
# with the `.update` method accepting whatever the output of `print_func` is.
#
# However, `H2MM_C` provides `Printer` as an abstract base class, that is recomended as the
# parent class of any `print_formatter`.
#
# Indeed, both `StdPrinter` and `IPyPrinter` are subclasses of `Printer`
#
# Below is the code for `IPyPlot`, which displays a plot each iteration

# %%
from itertools import product, chain

# %%
class IPyPlot(hm.Printer):
    """
    Class for plotting optimization progress on matplotlib axes.
    
    Parameters
    ----------
    
    stream: DiplayHandle
        DisplayHandle for where plots will be displayed
    nrow: int, optional
        number of rows of plots in output, the default is 1
    ncol: int, optional
        number of columns of plots in output, the default is 1
    xlim: tuple[tuple[tuple[int|float|str, int|float|str],...],...]
        nrow x ncol x 2 nested tuples, identifying min and max values
        for x axis of given [row][col] plot. If 'min' or 'max', take
        said values in arrays. Defautl is for 1x1 'min', 'max' values
    ylim: tuple[tuple[tuple[int|float|str, int|float|str],...],...]
        nrow x ncol x 2 nested tuples, identifying min and max values
        for y axis of given [row][col] plot. If 'min' or 'max', take
        said values in arrays. Defautl is for 1x1 'min', 'max' values
    plot_kwargs: dict, optional
        dictionary of keword argumetns given to ax.plot on first iteration
        Default is empty dictionary.
    **kwargs: dict
        kwargs handed to plt.subplots when creating initial figure and plots.
    """
    __slots__ = ('stream', 'fig', 'ax', 'data', 'lines', 'xlim', 'ylim', 'plot_kwargs')
    def __init__(self, stream, nrow=1, ncol=1, 
                 xlim=((('min', 'max'),),), ylim=((('min', 'max'),),),
                 plot_kwargs=None, **kwargs):
        if len(xlim) != nrow or len(ylim) != nrow:
            raise ValueError("xlim and ylim must be nrow x ncol array")
        if any(len(x) != ncol or len(y) != ncol for x, y in zip(xlim, ylim)):
            raise ValueError("xlim and ylim must be nrow x ncol x 2 array")
        if any(len(x) != 2 or len(y) != 2 for x, y in chain.from_iterable(zip(xx,yy) for xx, yy in zip(xlim, ylim))):
            raise ValueError("xlim and ylim must be nrow x ncol x 2 array")
        self.stream = stream
        self.fig, ax = plt.subplots(nrow, ncol, **kwargs)
        self.ax = np.atleast_2d(ax)
        self.data = False
        self.stream.display(self.fig)
        self.xlim = xlim
        self.ylim = ylim
        self.plot_kwargs = plot_kwargs if plot_kwargs is not None else dict()

    def update(self, data):
        """
        Update plot with new data points

        Parameters
        ----------
        data : list[list[np.ndarray]]
            An array-like nrow x ncol object, with each pair of elements
            being an x-y value pair to plot.

        Returns
        -------
        None.

        """
        if isinstance(data, str):
            return
        if self.data is False:
            self.data = np.empty(self.ax.shape, dtype=np.object_)
            self.lines = np.empty(self.ax.shape, dtype=np.object_)
            for i, j in product(range(self.ax.shape[0]), range(self.ax.shape[1])):
                self.data[i,j] = data[i][j][np.newaxis]
                self.lines[i,j] = self.ax[i,j].plot(*self.data[i,j].T, **self.plot_kwargs)
        else:
            for i, j in product(range(self.ax.shape[0]), range(self.ax.shape[1])):
                self.data[i,j] = np.concatenate([self.data[i,j], data[i][j][np.newaxis]])
                for k, line in enumerate(self.lines[i,j]):
                    line.set_xdata(self.data[i,j][:,2*k])
                    line.set_ydata(self.data[i,j][:,2*k+1])
        for i, j in product(range(self.ax.shape[0]), range(self.ax.shape[1])):
            xmin, xmax = self.xlim[i][j]
            if xmin == 'min':
                xmin = np.min(self.data[i,j][:,::2])
            if xmax == 'max':
                xmax = np.max(self.data[i,j][:,::2])
            ymin, ymax = self.ylim[i][j]
            if ymin == 'min':
                ymin = np.min(self.data[i,j][:,1::2])
            if ymax == 'max':
                ymax = np.max(self.data[i,j][:,1::2])
            if xmin == xmax:
                xmin -= 1.0
                xmax += 1.0
            if ymin == ymax:
                ymin -= 1.0
                ymax += 1.0
            self.ax[i,j].set_xlim([xmin, xmax])
            self.ax[i,j].set_ylim([ymin, ymax])
        self.stream.update(self.fig)

    def close(self):
        """
        Clear the display handle.

        Returns
        -------
        None.

        """
        clear_output()
        
def plot_bic(niter, new, current, old, iter_time, total_time):
    """Printing function for IPyPlot, plots BIC in single plot"""
    return [[np.array([niter, current.bic])]]

def plot_obs(niter, new, current, old, iter_time, total_time, dx=0, dy=1):
    return [[np.array([[current.obs[i,dx], current.obs[i,dy]] for i in range(current.nstate)]).reshape(-1)]]

def plot_obs_bic(niter, new, current, old, iter_time, total_time, dx=0, dy=1):
    return [[np.array([niter, current.bic]), np.array([[current.obs[i,dx], current.obs[i,dy]] for i in range(current.nstate)]).reshape(-1)]]

# %%
model = hm.factory_h2mm_model(2,3)
model.optimize(color3, times3, print_formatter=IPyPlot, 
               print_stream=DisplayHandle(), print_func=plot_obs, print_fmt_kwargs=dict(xlim=(((0,1),),), ylim=(((0,1),),)))
# Out:
# nstate: 2, ndet: 3, nphot: 436084, niter: 84, loglik: -416808.4605439942 converged state: 0x27
# prior:
# 0.284200554143071, 0.715799445856929
# trans:
# 0.9999702727150822, 2.9727284917793736e-05
# 1.3614951882954524e-05, 0.999986385048117
# obs:
# 0.1558440237836963, 0.26498198690992186, 0.5791739893063819
# 0.5300104078320693, 0.08194015753820581, 0.388049434629725
