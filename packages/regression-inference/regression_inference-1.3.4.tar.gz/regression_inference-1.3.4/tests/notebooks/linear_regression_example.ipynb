# %%
import pandas as pd
import numpy as np
from regression_inference import *
import matplotlib.pyplot as plt

# %%
gss = pd.read_csv('../../../Research Assessment/gss.csv', low_memory=False) 
gss_model = gss.loc[gss["yrint"] == 2010].dropna(subset=['paeduc', 'maeduc', 'age', 'educ'])
X, y = gss_model[['paeduc', 'maeduc', 'age']], gss_model['educ']

# %%
X_numpy = np.hstack([np.ones((np.asarray(X, dtype=float).shape[0], 1)), np.asarray(X, dtype=float)])
y_numpy = np.asarray(y, dtype=float)
np_model = LinearRegression().fit(X=X_numpy, y=y_numpy, feature_names=['paeduc','maeduc','age'], target_name="Education")
print(X_numpy, y_numpy)
print(np_model)
# Out:
# [[ 1.  8.  3. 31.]
#  [ 1. 18.  6. 23.]
#  [ 1.  2.  0. 82.]
#  ...
#  [ 1. 12. 14. 54.]
#  [ 1.  6. 12. 57.]
#  [ 1. 12. 12. 30.]] [16. 16. 10. ... 12. 16. 14.]
# =============================================
# OLS Regression Results
# ---------------------------------------------
# Dependent:                          Education
# ---------------------------------------------
#
# const                               7.3256***
#                                      (0.3684)
#
# paeduc                              0.2144***
#                                      (0.0241)
#
# maeduc                              0.2569***
#                                      (0.0271)
#
# age                                 0.0241***
#                                      (0.0043)
#
# ---------------------------------------------
# R-squared                               0.276
# Adjusted R-squared                      0.274
# F Statistic                           177.548
# Observations                         1402.000
# Log Likelihood                      -3359.107
# AIC                                  6726.213
# BIC                                  6747.196
# TSS                                 13663.270
# RSS                                  9893.727
# ESS                                  3769.543
# MSE                                     7.077
# =============================================
# *p<0.1; **p<0.05; ***p<0.01

# %%
X_const = X.copy()
X_const.insert(0, 'const', np.ones(len(X)))
model = LinearRegression().fit(X=X_const, y=y, alpha=0.05)
print(model)
# Out:
# =============================================
# OLS Regression Results
# ---------------------------------------------
# Dependent:                               educ
# ---------------------------------------------
#
# const                               7.3256***
#                                      (0.3684)
#
# paeduc                              0.2144***
#                                      (0.0241)
#
# maeduc                              0.2569***
#                                      (0.0271)
#
# age                                 0.0241***
#                                      (0.0043)
#
# ---------------------------------------------
# R-squared                               0.276
# Adjusted R-squared                      0.274
# F Statistic                           177.548
# Observations                         1402.000
# Log Likelihood                      -3359.107
# AIC                                  6726.213
# BIC                                  6747.196
# TSS                                 13663.270
# RSS                                  9893.727
# ESS                                  3769.543
# MSE                                     7.077
# =============================================
# *p<0.1; **p<0.05; ***p<0.01

# %%
model
# Out:
# LinearRegression(feature_names=Index(['const', 'paeduc', 'maeduc', 'age'], dtype='object'), target='educ', alpha=0.05, theta=array([7.32564767, 0.21441961, 0.25693439, 0.02412266]), coefficients=array([0.21441961, 0.25693439, 0.02412266]), intercept=np.float64(7.3256476651517755), predictions=array([10.55961033, 13.28162833,  9.73254533, ..., 14.79838836,
#        13.07036988, 13.70557564], shape=(1402,)), degrees_freedom=1398, log_likelihood=np.float64(-3359.1065993621455), aic=np.float64(6726.213198724291), bic=np.float64(6747.195818994669), p_value_coefficient=array([0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 2.90268838e-08]), variance_coefficient=array([[ 1.35692146e-01, -2.13408947e-03, -4.08009349e-03,
#         -1.20819874e-03],
#        [-2.13408947e-03,  5.83097905e-04, -4.47165379e-04,
#          1.18030685e-05],
#        [-4.08009349e-03, -4.47165379e-04,  7.35721575e-04,
#          1.45253440e-05],
#        [-1.20819874e-03,  1.18030685e-05,  1.45253440e-05,
#          1.86963400e-05]]), std_error_coefficient=array([0.36836415, 0.02414742, 0.02712419, 0.00432393]), ci_low=array([6.60304159, 0.16705053, 0.20372589, 0.01564058]), ci_high=array([8.04825374, 0.2617887 , 0.31014289, 0.03260475]), rss=np.float64(9893.726756472599), tss=np.float64(13663.26961483595), ess=np.float64(3769.5428583633757), mse=np.float64(7.077057765717167), rmse=np.float64(2.6602740020000133), f_statistic=np.float64(177.54755262956286), r_squared=np.float64(0.27588878538049777), r_squared_adjusted=np.float64(0.2743348986538465), t_stat_coefficient=array([19.88697241,  8.87960749,  9.47251919,  5.5788793 ]))

# %%
print(summary(model, np_model))
# Out:
# ============================================================
# OLS Regression Results
# ------------------------------------------------------------
# Dependent:                               educ      Education
# ------------------------------------------------------------
#
# const                               7.3256***      7.3256***
#                                      (0.3684)       (0.3684)
#
# paeduc                              0.2144***      0.2144***
#                                      (0.0241)       (0.0241)
#
# maeduc                              0.2569***      0.2569***
#                                      (0.0271)       (0.0271)
#
# age                                 0.0241***      0.0241***
#                                      (0.0043)       (0.0043)
#
# ------------------------------------------------------------
# R-squared                               0.276          0.276
# Adjusted R-squared                      0.274          0.274
# F Statistic                           177.548        177.548
# Observations                         1402.000       1402.000
# Log Likelihood                      -3359.107      -3359.107
# AIC                                  6726.213       6726.213
# BIC                                  6747.196       6747.196
# TSS                                 13663.270      13663.270
# RSS                                  9893.727       9893.727
# ESS                                  3769.543       3769.543
# MSE                                     7.077          7.077
# ============================================================
# *p<0.1; **p<0.05; ***p<0.01

# %%
pd.DataFrame(model.inference_table())
# Out:
#   feature coefficient std_error  t_statistic  P>|t| ci_low_0.05 ci_high_0.05
# 0   const      7.3256    0.3684      19.8870  0.000       6.603       8.0483
# 1  paeduc      0.2144    0.0241       8.8796  0.000      0.1671       0.2618
# 2  maeduc      0.2569    0.0271       9.4725  0.000      0.2037       0.3101
# 3     age      0.0241    0.0043       5.5789  0.000      0.0156       0.0326

# %%
pd.DataFrame(model.variance_inflation_factor())
# Out:
#   feature     VIF
# 0  paeduc  2.0233
# 1  maeduc  2.0285
# 2     age  1.0971

# %%
pd.DataFrame(model.robust_se(type="HC3"))
# Out:
#   feature  robust_se   robust_t      robust_p  ci_low_0.05  ci_high_0.05
# 0   const   0.434460  16.861504  0.000000e+00     6.473384      8.177911
# 1  paeduc   0.023602   9.084741  0.000000e+00     0.168120      0.260719
# 2  maeduc   0.029439   8.727734  0.000000e+00     0.199185      0.314683
# 3     age   0.004221   5.715290  1.336690e-08     0.015843      0.032402

# %%
X_const = X.copy()
X_const.insert(0, 'const', np.ones(len(X)))
robust_model = LinearRegression().fit(X_const, y, cov_type="HC3")
robust_model.target = "robust educ"
print(summary(model, robust_model))
# Out:
# ============================================================
# OLS Regression Results
# ------------------------------------------------------------
# Dependent:                               educ    robust educ
# ------------------------------------------------------------
#
# const                               7.3256***      7.3256***
#                                      (0.3684)       (0.4345)
#
# paeduc                              0.2144***      0.2144***
#                                      (0.0241)       (0.0236)
#
# maeduc                              0.2569***      0.2569***
#                                      (0.0271)       (0.0294)
#
# age                                 0.0241***      0.0241***
#                                      (0.0043)       (0.0042)
#
# ------------------------------------------------------------
# R-squared                               0.276          0.276
# Adjusted R-squared                      0.274          0.274
# F Statistic                           177.548        177.548
# Observations                         1402.000       1402.000
# Log Likelihood                      -3359.107      -3359.107
# AIC                                  6726.213       6726.213
# BIC                                  6747.196       6747.196
# TSS                                 13663.270      13663.270
# RSS                                  9893.727       9893.727
# ESS                                  3769.543       3769.543
# MSE                                     7.077          7.077
# ============================================================
# *p<0.1; **p<0.05; ***p<0.01

# %%
pd.DataFrame(model.inference_table())
# Out:
#   feature coefficient std_error  t_statistic  P>|t| ci_low_0.05 ci_high_0.05
# 0   const      7.3256    0.3684      19.8870  0.000       6.603       8.0483
# 1  paeduc      0.2144    0.0241       8.8796  0.000      0.1671       0.2618
# 2  maeduc      0.2569    0.0271       9.4725  0.000      0.2037       0.3101
# 3     age      0.0241    0.0043       5.5789  0.000      0.0156       0.0326

# %%
pd.DataFrame(robust_model.inference_table())
# Out:
#   feature coefficient std_error  t_statistic  P>|t| ci_low_0.05 ci_high_0.05
# 0   const      7.3256    0.4345      16.8615  0.000      6.4734       8.1779
# 1  paeduc      0.2144    0.0236       9.0847  0.000      0.1681       0.2607
# 2  maeduc      0.2569    0.0294       8.7277  0.000      0.1992       0.3147
# 3     age      0.0241    0.0042       5.7153  0.000      0.0158       0.0324

# %%
model.feature_names[1:]
# Out:
# Index(['paeduc', 'maeduc', 'age'], dtype='object')

# %%
model.predict(np.array([[0, 0, 0], ]))
# Out:
# array([7.32564767])

# %%
prediction_set = [
    np.array([[0, 0, 0], ]),
    np.array([[X['paeduc'].mean(), X['maeduc'].mean(), X['age'].mean(),], ]),
    np.array([[X['paeduc'].mean(), 14,  X['age'].mean()], ]),
    np.array([[11.624822, 11.659058, 48.225392], ]),
    np.array([[8, 14,  X['age'].mean()], ]),
] 
predictions = pd.concat([pd.DataFrame(model.predict(test_set, return_table=True)) for test_set in prediction_set], ignore_index=True)
predictions
# Out:
#                                             features  prediction  std_error  \
# 0  {'paeduc': '0.00', 'maeduc': '0.00', 'age': '0...      7.3256     0.3684
# 1  {'paeduc': '11.62', 'maeduc': '11.66', 'age': ...     13.9772     0.0710
# 2  {'paeduc': '11.62', 'maeduc': '14.00', 'age': ...     14.5786     0.0953
# 3  {'paeduc': '11.62', 'maeduc': '11.66', 'age': ...     13.9772     0.0710
# 4  {'paeduc': '8.00', 'maeduc': '14.00', 'age': '...     13.8014     0.1560
#
#    t_statistic  P>|t|  ci_low_0.05  ci_high_0.05
# 0      19.8870  0.000       6.6030        8.0483
# 1     196.7284  0.000      13.8378       14.1165
# 2     152.9974  0.000      14.3917       14.7656
# 3     196.7284  0.000      13.8378       14.1165
# 4      88.4816  0.000      13.4954       14.1074

# %%
model.feature_names[1:]
# Out:
# Index(['paeduc', 'maeduc', 'age'], dtype='object')

# %%
'''Incremental predictions holding other values at sample mean'''

prediction_set = [
    (np.array([[i, X['maeduc'].mean(), X['age'].mean()],]))
    for i in range(int(X['paeduc'].min()), int(X['paeduc'].max())+1)
    ] 
predictions = pd.concat([pd.DataFrame(model.predict(i, return_table=True)) for i in prediction_set], ignore_index=True)
predictions
# Out:
#                                              features  prediction  std_error  \
# 0   {'paeduc': '0.00', 'maeduc': '11.66', 'age': '...     11.4846     0.2896
# 1   {'paeduc': '1.00', 'maeduc': '11.66', 'age': '...     11.6990     0.2662
# 2   {'paeduc': '2.00', 'maeduc': '11.66', 'age': '...     11.9134     0.2430
# 3   {'paeduc': '3.00', 'maeduc': '11.66', 'age': '...     12.1278     0.2201
# 4   {'paeduc': '4.00', 'maeduc': '11.66', 'age': '...     12.3423     0.1974
# 5   {'paeduc': '5.00', 'maeduc': '11.66', 'age': '...     12.5567     0.1750
# 6   {'paeduc': '6.00', 'maeduc': '11.66', 'age': '...     12.7711     0.1533
# 7   {'paeduc': '7.00', 'maeduc': '11.66', 'age': '...     12.9855     0.1324
# 8   {'paeduc': '8.00', 'maeduc': '11.66', 'age': '...     13.1999     0.1127
# 9   {'paeduc': '9.00', 'maeduc': '11.66', 'age': '...     13.4144     0.0952
# 10  {'paeduc': '10.00', 'maeduc': '11.66', 'age': ...     13.6288     0.0812
# 11  {'paeduc': '11.00', 'maeduc': '11.66', 'age': ...     13.8432     0.0726
# 12  {'paeduc': '12.00', 'maeduc': '11.66', 'age': ...     14.0576     0.0716
# 13  {'paeduc': '13.00', 'maeduc': '11.66', 'age': ...     14.2720     0.0784
# 14  {'paeduc': '14.00', 'maeduc': '11.66', 'age': ...     14.4865     0.0913
# 15  {'paeduc': '15.00', 'maeduc': '11.66', 'age': ...     14.7009     0.1081
# 16  {'paeduc': '16.00', 'maeduc': '11.66', 'age': ...     14.9153     0.1273
# 17  {'paeduc': '17.00', 'maeduc': '11.66', 'age': ...     15.1297     0.1480
# 18  {'paeduc': '18.00', 'maeduc': '11.66', 'age': ...     15.3441     0.1695
# 19  {'paeduc': '19.00', 'maeduc': '11.66', 'age': ...     15.5586     0.1917
# 20  {'paeduc': '20.00', 'maeduc': '11.66', 'age': ...     15.7730     0.2144
#
#     t_statistic  P>|t|  ci_low_0.05  ci_high_0.05
# 0       39.6620  0.000      10.9166       12.0526
# 1       43.9452  0.000      11.1768       12.2212
# 2       49.0201  0.000      11.4367       12.3902
# 3       55.1134  0.000      11.6962       12.5595
# 4       62.5393  0.000      11.9551       12.7294
# 5       71.7361  0.000      12.2133       12.9001
# 6       83.3162  0.000      12.4704       13.0718
# 7       98.1061  0.000      12.7259       13.2452
# 8      117.0875  0.000      12.9788       13.4211
# 9      140.8904  0.000      13.2276       13.6011
# 10     167.9212  0.000      13.4696       13.7880
# 11     190.5925  0.000      13.7007       13.9857
# 12     196.2714  0.000      13.9171       14.1981
# 13     181.9825  0.000      14.1182       14.4259
# 14     158.6529  0.000      14.3073       14.6656
# 15     135.9656  0.000      14.4888       14.9130
# 16     117.1510  0.000      14.6655       15.1651
# 17     102.2488  0.000      14.8395       15.4200
# 18      90.5001  0.000      15.0115       15.6767
# 19      81.1438  0.000      15.1824       15.9347
# 20      73.5832  0.000      15.3525       16.1935

# %%
plt.plot(list(range(0, len(predictions['prediction']))), predictions['prediction'], color="red", label=" ")
plt.fill_between(list(range(0, len(predictions['prediction']))), predictions['ci_low_0.05'], predictions['ci_high_0.05'], color="red", alpha=0.3)
plt.show()

# %%
dydx = [predictions['prediction'][i+1] - predictions['prediction'][i] for i in list(range(0, len(predictions['prediction'])-1))]
dydx = dydx.copy()
dydx.insert(0, 0)

ci_low_dydx, ci_high_dydx = predictions['ci_low_0.05'], predictions['ci_high_0.05']
dydx_low_ci = [ci_low_dydx[i+1] - ci_low_dydx[i] for i in list(range(0, len(predictions['prediction'])-1))]
dydx_high_ci = [ci_high_dydx[i+1] - ci_high_dydx[i] for i in list(range(0, len(predictions['prediction'])-1))]

dydx_low_ci.insert(0, 0)
dydx_high_ci.insert(0, 0)

derivative_predictions = predictions[['features']].copy()
derivative_predictions['derivative'] = dydx
derivative_predictions['ci_low_dydx'] = dydx_low_ci
derivative_predictions['ci_high_dydx'] = dydx_high_ci

# %%
derivative_predictions
# Out:
#                                              features  derivative  \
# 0   {'paeduc': '0.00', 'maeduc': '11.66', 'age': '...      0.0000
# 1   {'paeduc': '1.00', 'maeduc': '11.66', 'age': '...      0.2144
# 2   {'paeduc': '2.00', 'maeduc': '11.66', 'age': '...      0.2144
# 3   {'paeduc': '3.00', 'maeduc': '11.66', 'age': '...      0.2144
# 4   {'paeduc': '4.00', 'maeduc': '11.66', 'age': '...      0.2145
# 5   {'paeduc': '5.00', 'maeduc': '11.66', 'age': '...      0.2144
# 6   {'paeduc': '6.00', 'maeduc': '11.66', 'age': '...      0.2144
# 7   {'paeduc': '7.00', 'maeduc': '11.66', 'age': '...      0.2144
# 8   {'paeduc': '8.00', 'maeduc': '11.66', 'age': '...      0.2144
# 9   {'paeduc': '9.00', 'maeduc': '11.66', 'age': '...      0.2145
# 10  {'paeduc': '10.00', 'maeduc': '11.66', 'age': ...      0.2144
# 11  {'paeduc': '11.00', 'maeduc': '11.66', 'age': ...      0.2144
# 12  {'paeduc': '12.00', 'maeduc': '11.66', 'age': ...      0.2144
# 13  {'paeduc': '13.00', 'maeduc': '11.66', 'age': ...      0.2144
# 14  {'paeduc': '14.00', 'maeduc': '11.66', 'age': ...      0.2145
# 15  {'paeduc': '15.00', 'maeduc': '11.66', 'age': ...      0.2144
# 16  {'paeduc': '16.00', 'maeduc': '11.66', 'age': ...      0.2144
# 17  {'paeduc': '17.00', 'maeduc': '11.66', 'age': ...      0.2144
# 18  {'paeduc': '18.00', 'maeduc': '11.66', 'age': ...      0.2144
# 19  {'paeduc': '19.00', 'maeduc': '11.66', 'age': ...      0.2145
# 20  {'paeduc': '20.00', 'maeduc': '11.66', 'age': ...      0.2144
#
#     ci_low_dydx  ci_high_dydx
# 0        0.0000        0.0000
# 1        0.2602        0.1686
# 2        0.2599        0.1690
# 3        0.2595        0.1693
# 4        0.2589        0.1699
# 5        0.2582        0.1707
# 6        0.2571        0.1717
# 7        0.2555        0.1734
# 8        0.2529        0.1759
# 9        0.2488        0.1800
# 10       0.2420        0.1869
# 11       0.2311        0.1977
# 12       0.2164        0.2124
# 13       0.2011        0.2278
# 14       0.1891        0.2397
# 15       0.1815        0.2474
# 16       0.1767        0.2521
# 17       0.1740        0.2549
# 18       0.1720        0.2567
# 19       0.1709        0.2580
# 20       0.1701        0.2588

# %%
derivatives_trim = derivative_predictions['derivative'][1:]
dydx_ci_low_trim, dydx_ci_high_trim = derivative_predictions['ci_low_dydx'][1:], derivative_predictions['ci_high_dydx'][1:]

plt.plot(list(range(0, len(derivatives_trim))), derivatives_trim, color="red", label=" ")
plt.fill_between(list(range(0, len(derivatives_trim))), dydx_ci_low_trim, dydx_ci_high_trim, color="red", alpha=0.3)
plt.show()
