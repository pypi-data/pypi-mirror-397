# %% [raw]
# ---
# title: Overview
# aliases:
#   - ../index.html
# jupyter:
#   kernelspec:
#     display_name: Python 3 (ipykernel)
#     language: python
#     name: python3
# ---

# %% [markdown]
# **munch-group-library** lets you ...
#
# {{< lipsum 1 >}}
#
# ## Installation
#
# ::: {.panel-tabset}
#
# ## Pixi
#
# ```bash
# pixi workspace channel add munch-group
# pixi add munch-group-library
# ```
#
# ## conda
#
# ```bash
# conda install -c munch-group munch-group-library
# ```
#
# ## Pip
#
# ```bash
# pip install munch-group-library
# ```
#
# :::
#
#
# ## Basic use
#
# ```python
#
# ```
#
# ## Some use case
#
# The [functionname function](`munch_group_library.modulename.functionname`) does ... [](`munch_group_library.modulename.functionname`) does ... [](`~munch_group_library.modulename.functionname`) does ...
#
# {{< lipsum 1 >}}

# %%
# from munch_group_library.modulename import functionname
# functionname(3, 4)

# %% [markdown]
# {{< lipsum 1 >}}
#
# ```yaml
# contents:
#   - MdRenderer
# ```
#
# {{< lipsum 1 >}}
#
# ## Learning more
#
# Go [to the anvanced page](overview.ipynb) to learn how to ...
#
# * [Examples page](overview.ipynb): sites using quartodoc.
