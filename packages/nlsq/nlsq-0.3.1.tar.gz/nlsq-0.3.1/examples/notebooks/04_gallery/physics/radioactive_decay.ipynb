# %% [markdown]
# # 📘 Radioactive Decay: Half-Life Determination> Fit exponential decay to nuclear decay data⏱️ **15-20 minutes** | 📊 **Level: ●●○ Intermediate** | 🏷️ **Physics** | 🔬 **Nuclear**---

# %% [markdown]
# ## 🔬 Domain Background**Model:** $N(t) = N_0 e^{-\lambda t}$**Where:**- $N_0$: Initial number of nuclei- $\lambda$: Decay constant- $t$: Time**Applications:** Dating, nuclear medicine, radiation safety---

# %% [markdown]
# ## Setup

# %%
# Configure matplotlib for inline plotting in VS Code/Jupyter
# MUST come before importing matplotlib
# %matplotlib inline

# %%
from IPython.display import display

# %%
import jax.numpy as jnp
import matplotlib.pyplot as plt
import numpy as np

from nlsq import curve_fit


def radioactive_decay(t, N0, lambda_decay):
    return N0 * jnp.exp(-lambda_decay * t)

# %% [markdown]
# ## Generate Decay Data

# %%
N0_true = 10000
lambda_true = 0.1  # 1/s
t = np.linspace(0, 50, 30)
N_true = radioactive_decay(t, N0_true, lambda_true)
N = N_true + np.random.normal(0, 100, len(t))

plt.semilogy(t, N, 'o', alpha=0.5, label='Measured counts')
plt.semilogy(t, N_true, 'r--', label='True decay')
plt.xlabel('Time (s)')
plt.ylabel('Count Rate')
plt.legend()
plt.tight_layout()
plt.tight_layout()
plt.show()
# Out:
# /tmp/ipykernel_751198/1188107962.py:14: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   plt.show()

# %% [markdown]
# ## Determine Half-Life

# %%
popt, pcov = curve_fit(radioactive_decay, t, N, p0=[9500, 0.09])
N0_fit, lambda_fit = popt
perr = np.sqrt(np.diag(pcov))

t_half = np.log(2) / lambda_fit
t_half_err = t_half * (perr[1] / lambda_fit)

print(f'Decay constant (λ): {lambda_fit:.4f} ± {perr[1]:.4f} s⁻¹')
print(f'Half-life (t₁/₂):    {t_half:.2f} ± {t_half_err:.2f} s')
print(f'\nAfter 1 half-life: {50}% remain')
print(f'After 2 half-lives: {25}% remain')
# Out:
# INFO:nlsq.curve_fit:Starting curve fit | {'n_params': 2, 'n_data_points': 30, 'method': 'trf', 'solver': 'auto', 'batch_size': None, 'has_bounds': False, 'dynamic_sizing': False}
# INFO:nlsq.least_squares:Starting least squares optimization | {'method': 'trf', 'n_params': 2, 'loss': 'linear', 'ftol': 1e-08, 'xtol': 1e-08, 'gtol': 1e-08}
# INFO:nlsq.optimizer.trf:Starting TRF optimization (no bounds) | {'n_params': 2, 'n_residuals': 30, 'max_nfev': None}
# PERFORMANCE:nlsq.optimizer.trf:Optimization: iter=0 | cost=6.177972e+05 | ‖∇f‖=8.053475e+07 | nfev=1
# PERFORMANCE:nlsq.optimizer.trf:Optimization: iter=1 | cost=1.528871e+05 | ‖∇f‖=4.309060e+06 | step=9.500000e+03 | nfev=2
# PERFORMANCE:nlsq.optimizer.trf:Optimization: iter=2 | cost=1.516604e+05 | ‖∇f‖=6.977931e+04 | step=9.500000e+03 | nfev=3
# PERFORMANCE:nlsq.optimizer.trf:Optimization: iter=3 | cost=1.516601e+05 | ‖∇f‖=8.814450e+02 | step=9.500000e+03 | nfev=4
# PERFORMANCE:nlsq.least_squares:Timer: optimization took 1.122605s
# INFO:nlsq.least_squares:Convergence: reason=`ftol` termination condition is satisfied. | iterations=4 | final_cost=1.516601e+05 | time=1.123s | final_gradient_norm=11.219867173960665
# PERFORMANCE:nlsq.curve_fit:Timer: curve_fit took 1.413637s
# INFO:nlsq.curve_fit:Curve fit completed | {'total_time': 1.4136369279876817, 'final_cost': 303320.2183251848, 'covariance_warning': False}
# Decay constant (λ): 0.0998 ± 0.0011 s⁻¹
# Half-life (t₁/₂):    6.94 ± 0.08 s
#
# After 1 half-life: 50% remain
# After 2 half-lives: 25% remain

# %% [markdown]
# ## Key Insights1. **Linear on log scale** confirms exponential decay2. **Half-life constant** - characteristic of isotope3. **Statistical fluctuations** inherent in nuclear decay---
