# %% [markdown]
# # 📘 Titration Curves: Acid-Base Equilibria> Determine pKa from titration data⏱️ **15-25 minutes** | 📊 **Level: ●●○ Intermediate** | 🏷️ **Chemistry**---

# %% [markdown]
# ## 🔬 Domain Background**Model:** $pH = pK_a + \log\frac{[A^-]}{[HA]}$**Applications:** pKa determination, buffer analysis---

# %% [markdown]
# ## Setup

# %%
# Configure matplotlib for inline plotting in VS Code/Jupyter
# MUST come before importing matplotlib
# %matplotlib inline

# %%
from IPython.display import display

# %%
import numpy as np
import jax.numpy as jnp
from nlsq import curve_fit
import matplotlib.pyplot as plt

def titration_curve(V, pKa, V_eq):
    fraction = V / V_eq
    fraction = jnp.clip(fraction, 1e-10, 1-1e-10)
    return pKa + jnp.log10(fraction / (1 - fraction))

# %% [markdown]
# ## Generate Data

# %%
pKa_true, V_eq_true = 4.76, 25.0
V = np.linspace(0.1, 49, 50)
pH_true = titration_curve(V, pKa_true, V_eq_true)
pH = pH_true + np.random.normal(0, 0.1, len(V))

plt.plot(V, pH, 'o')
plt.xlabel('Volume NaOH (mL)')
plt.ylabel('pH')
plt.tight_layout()
plt.tight_layout()
plt.show()
# Out:
# /tmp/ipykernel_743909/3213670498.py:11: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   plt.show()

# %% [markdown]
# ## Fit Model

# %%
mask = (V > 5) & (V < 45)
popt, pcov = curve_fit(titration_curve, V[mask], pH[mask], p0=[4.5, 24])
pKa_fit, V_eq_fit = popt

print(f'pKa: {pKa_fit:.2f}')
print(f'Equivalence point: {V_eq_fit:.1f} mL')
# Out:
# INFO:nlsq.curve_fit:Starting curve fit | {'n_params': 2, 'n_data_points': 40, 'method': 'trf', 'solver': 'auto', 'batch_size': None, 'has_bounds': False, 'dynamic_sizing': False}
# INFO:nlsq.least_squares:Starting least squares optimization | {'method': 'trf', 'n_params': 2, 'loss': 'linear', 'ftol': 1e-08, 'xtol': 1e-08, 'gtol': 1e-08}
# INFO:nlsq.optimizer.trf:Starting TRF optimization (no bounds) | {'n_params': 2, 'n_residuals': 40, 'max_nfev': None}
# PERFORMANCE:nlsq.optimizer.trf:Optimization: iter=0 | cost=3.610695e+01 | ‖∇f‖=4.240650e-01 | nfev=1
# PERFORMANCE:nlsq.optimizer.trf:Optimization: iter=1 | cost=3.607140e+01 | ‖∇f‖=1.413213e-01 | step=3.811620e-01 | nfev=3
# PERFORMANCE:nlsq.optimizer.trf:Optimization: iter=2 | cost=3.606962e+01 | ‖∇f‖=2.416649e-01 | step=9.173666e-02 | nfev=4
# PERFORMANCE:nlsq.optimizer.trf:Optimization: iter=3 | cost=3.605608e+01 | ‖∇f‖=7.201112e-02 | step=1.834733e-01 | nfev=5
# PERFORMANCE:nlsq.optimizer.trf:Optimization: iter=4 | cost=3.605425e+01 | ‖∇f‖=2.084209e-02 | step=1.834733e-01 | nfev=6
# PERFORMANCE:nlsq.optimizer.trf:Optimization: iter=5 | cost=3.605407e+01 | ‖∇f‖=1.111733e-02 | step=1.834733e-01 | nfev=7
# PERFORMANCE:nlsq.optimizer.trf:Optimization: iter=6 | cost=3.605402e+01 | ‖∇f‖=4.663101e-03 | step=1.834733e-01 | nfev=8
# PERFORMANCE:nlsq.optimizer.trf:Optimization: iter=7 | cost=3.605401e+01 | ‖∇f‖=2.185958e-03 | step=1.834733e-01 | nfev=9
# PERFORMANCE:nlsq.optimizer.trf:Optimization: iter=8 | cost=3.605401e+01 | ‖∇f‖=9.753315e-04 | step=1.834733e-01 | nfev=10
# PERFORMANCE:nlsq.optimizer.trf:Optimization: iter=9 | cost=3.605401e+01 | ‖∇f‖=4.450993e-04 | step=1.834733e-01 | nfev=11
# PERFORMANCE:nlsq.least_squares:Timer: optimization took 1.402712s
# INFO:nlsq.least_squares:Convergence: reason=`ftol` termination condition is satisfied. | iterations=10 | final_cost=3.605401e+01 | time=1.403s | final_gradient_norm=0.00020106624191501554
# PERFORMANCE:nlsq.curve_fit:Timer: curve_fit took 2.019344s
# INFO:nlsq.curve_fit:Curve fit completed | {'total_time': 2.019344155007275, 'final_cost': 72.10802533542709, 'covariance_warning': False}
# pKa: 4.49
# Equivalence point: 23.6 mL

# %% [markdown]
# ## Key Insights1. **pKa at half-equivalence point**2. **Buffer capacity maximum at pH = pKa**---
