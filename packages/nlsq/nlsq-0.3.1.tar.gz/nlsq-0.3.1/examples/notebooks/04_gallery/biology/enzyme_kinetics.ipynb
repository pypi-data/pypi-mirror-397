# %% [markdown]
# # 📘 Enzyme Kinetics: Michaelis-Menten Analysis> Fit Michaelis-Menten model to enzyme velocity data⏱️ **15-25 minutes** | 📊 **Level: ●●○ Intermediate** | 🏷️ **Biology** | 🔬 **Biochemistry**---

# %% [markdown]
# ## 🔬 Domain Background**Model:** $v = \frac{V_{max}[S]}{K_m + [S]}$**Applications:** Enzyme characterization, drug screening---

# %% [markdown]
# ## Setup

# %%
# Configure matplotlib for inline plotting in VS Code/Jupyter
# MUST come before importing matplotlib
# %matplotlib inline

# %%
from IPython.display import display

# %%
import numpy as np
import jax.numpy as jnp
from nlsq import curve_fit
import matplotlib.pyplot as plt

def michaelis_menten(S, Vmax, Km):
    return Vmax * S / (Km + S)

# %% [markdown]
# ## Generate Data

# %%
Vmax_true, Km_true = 100, 50
S = np.array([1,2,5,10,20,50,100,200,500])
v_true = michaelis_menten(S, Vmax_true, Km_true)
v = v_true + np.random.normal(0, 3, len(S))

plt.plot(S, v, 'o')
plt.xlabel('[S] (µM)')
plt.ylabel('v (µM/s)')
plt.tight_layout()
plt.tight_layout()
plt.show()
# Out:
# /tmp/ipykernel_745013/3834656988.py:11: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   plt.show()

# %% [markdown]
# ## Fit Model

# %%
popt, pcov = curve_fit(michaelis_menten, S, v, p0=[80, 40])
Vmax_fit, Km_fit = popt

print(f'Vmax: {Vmax_fit:.1f} µM/s')
print(f'Km: {Km_fit:.1f} µM')
# Out:
# INFO:nlsq.curve_fit:Starting curve fit | {'n_params': 2, 'n_data_points': 9, 'method': 'trf', 'solver': 'auto', 'batch_size': None, 'has_bounds': False, 'dynamic_sizing': False}
# INFO:nlsq.least_squares:Starting least squares optimization | {'method': 'trf', 'n_params': 2, 'loss': 'linear', 'ftol': 1e-08, 'xtol': 1e-08, 'gtol': 1e-08}
# INFO:nlsq.optimizer.trf:Starting TRF optimization (no bounds) | {'n_params': 2, 'n_residuals': 9, 'max_nfev': None}
# PERFORMANCE:nlsq.optimizer.trf:Optimization: iter=0 | cost=2.924931e+02 | ‖∇f‖=3.480171e+01 | nfev=1
# PERFORMANCE:nlsq.optimizer.trf:Optimization: iter=1 | cost=5.378662e+01 | ‖∇f‖=2.703443e-02 | step=8.944272e+01 | nfev=2
# PERFORMANCE:nlsq.optimizer.trf:Optimization: iter=2 | cost=5.378632e+01 | ‖∇f‖=6.920992e-04 | step=8.944272e+01 | nfev=3
# PERFORMANCE:nlsq.least_squares:Timer: optimization took 1.028356s
# INFO:nlsq.least_squares:Convergence: reason=`ftol` termination condition is satisfied. | iterations=3 | final_cost=5.378632e+01 | time=1.028s | final_gradient_norm=3.886409131470536e-05
# PERFORMANCE:nlsq.curve_fit:Timer: curve_fit took 1.388412s
# INFO:nlsq.curve_fit:Curve fit completed | {'total_time': 1.3884123179886956, 'final_cost': 107.57263920942779, 'covariance_warning': False}
# Vmax: 93.8 µM/s
# Km: 40.1 µM

# %% [markdown]
# ## Key Insights1. **Km indicates affinity** - Lower Km = higher substrate affinity2. **Vmax depends on enzyme amount**---
