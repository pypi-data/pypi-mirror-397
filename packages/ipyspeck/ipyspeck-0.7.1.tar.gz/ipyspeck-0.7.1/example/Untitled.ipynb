# %%
import ipyspeck

H2O='''3
Water molecule
O          0.00000        0.00000        0.11779
H          0.00000        0.75545       -0.47116
H          0.00000       -0.75545       -0.47116'''
h2o = ipyspeck.speck.Speck(data=H2O)
h2o
# Out:
# Speck(data='3\nWater molecule\nO          0.00000        0.00000        0.11779\nH          0.00000        0.7…
